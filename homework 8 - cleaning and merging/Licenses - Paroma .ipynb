# %% [markdown]
# # Texas Licenses
#
# I originally got this dataset from the [License Files page](https://www.license.state.tx.us/licensesearch/licfile.asp) from the Texas Department of Licensing and Regulation, but they've changed around since then! I'm pretty sure it's [this dataset](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but we'll just use a local version instead of the most current.

# %% [markdown]
# # PART ONE: OPENING UP OUR DATASET

# %% [markdown]
# ## 0. Do your setup
#
# Import what you need to import, etc.

# %%
import pandas as pd
# Out:
# /Users/paromasoni/.pyenv/versions/3.8.2/lib/python3.8/site-packages/pandas/compat/__init__.py:120: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %% [markdown]
# ## 1. Open the file
#
# We'll start with `licfile.csv`, which is a list of licenses.

# %%
df = pd.read_csv ("licfile.csv")
df.head()
# Out:
# /Users/paromasoni/.pyenv/versions/3.8.2/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (1,15,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Associate Auctioneer   7326      ANGELINA      RISINGER, JIM MARVIN  \
# 0  Associate Auctioneer   7962        UPSHUR       WILLIAMS, JON ANDRE
# 1  Associate Auctioneer   8406        WILSON     GUEVARA, JUAN ANTONIO
# 2  Associate Auctioneer  10543        HARRIS  BOWERS, JAMES BRISCOE II
# 3  Associate Auctioneer  10642          BELL       DEMSKY, JOHN EDWARD
# 4  Associate Auctioneer  15650  OUT OF STATE         THOMPSON, RANDY D
#
#    Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  08102017  \
# 0         NaN         NaN         NaN         NaN  12292017
# 1         NaN         NaN         NaN         NaN   9262017
# 2         NaN         NaN         NaN         NaN  11042017
# 3         NaN         NaN         NaN         NaN   2252018
# 4         NaN         NaN         NaN         NaN   5042017
#
#      RISINGER, JIM MARVIN.1     7668 S US HWY 59 Unnamed: 11  \
# 0       WILLIAMS, JON ANDRE          228 FM 1252         NaN
# 1     GUEVARA, JUAN ANTONIO         6909 HWY 181         NaN
# 2  BOWERS, JAMES BRISCOE II       6767 NORTH FWY         NaN
# 3       DEMSKY, JOHN EDWARD       130 E CLARK ST         NaN
# 4         THOMPSON, RANDY D  10995 BELLEVILLE RD         NaN
#
#     NACOGDOCHES TX 75964   0347   NACOGDOCHES  75964  9363665745 Unnamed: 17  \
# 0       KILGORE TX 75662  183.0         GREGG  75662  9039187899         NaN
# 1          POTH TX 78147  493.0        WILSON  78147         NaN         NaN
# 2  HOUSTON TX 77076-2027  201.0        HARRIS  77076  7136445566         NaN
# 3      BARTLETT TX 76511   27.0          BELL  76511  2549852228         NaN
# 4      RINGLING OK 73456  999.0  OUT OF STATE  73456  5802765961         NaN
#
#    N
# 0  N
# 1  N
# 2  N
# 3  N
# 4  N

# %% [markdown]
# ## 2. That looks terrible, let's add column names.
#
# It apparently doesn't have headers! **Read the file in again, but setting your own column names**. Their [current data dictionary might not perfectly match](https://www.opendatanetwork.com/dataset/data.texas.gov/7358-krk7), but you can use it to understand what the columns are. For the dataset we're using, the order goes like this:
#
# * LICTYPE
# * LICNUMBER
# * BIZCOUNTY
# * BIZNAME
# * BIZLINE1
# * BIZLINE2
# * BIZCITYSTATE
# * BIZTELEPHONE
# * EXPIRATION
# * OWNER
# * MAILLINE1
# * MAILLINE2
# * MAILCITYSTATE
# * MAILCOUNTYCODE
# * MAILCOUNTY
# * MAILZIP
# * TELEPHONE
# * LICSUBTYPE
# * CEFLAG
#
# **Note:** You can rename the columns to things that make sense - "expiration" is a little more manageable than "LICENSE EXPIRATION DATE (MMDDCCYY)". I've named my License Type column LICTYPE, so if you haven't you'll have to change the rest of my sample code to match.

# %%
# df = pd.read_csv ("licfile.csv", names=['LICTYPE','LICNUMBER','BIZCOUNTY','BIZNAME','BIZLINE1','BIZLINE2','BIZCITYSTATE','BIZTELEPHONE','EXPIRATION','OWNER','MAILLINE1','MAILLINE2','MAILCITYSTATE','MAILCOUNTYCODE','MAILCOUNTY','MAILZIP','TELEPHONE','LICSUBTYPE','CEFLAG'])
# df.head()

# %%
#df.info()

# %% [markdown]
# # 3. Force string columns to be strings
#
# The county code and expiration dates are being read in as numbers, which is going to cause some trouble later on. You can force a column to be a certain type (most usually strings) when reading it in with the following code:
#
#     df = pd.read_csv("your-filename.csv", dtype={"colname1": str, "colname2": str})
#
# You don't need to do it for every column, just the ones you want to force!
#
# **Re-import the file, forcing the expiration date, license number, mailing address county code, mailing zip code and telephone to all be strings.**

# %%
df = pd.read_csv ("licfile.csv", names=['LICTYPE','LICNUMBER','BIZCOUNTY','BIZNAME','BIZLINE1','BIZLINE2','BIZCITYSTATE','BIZTELEPHONE','EXPIRATION','OWNER','MAILLINE1','MAILLINE2','MAILCITYSTATE','MAILCOUNTYCODE','MAILCOUNTY','MAILZIP','TELEPHONE','LICSUBTYPE','CEFLAG'],
                  dtype={ 'LICNUMBER': str,'BIZTELEPHONE': str, 'EXPIRATION': str,'MAILCOUNTYCODE': str,'TELEPHONE': str})
df.head()
# Out:
# /Users/paromasoni/.pyenv/versions/3.8.2/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3145: DtypeWarning: Columns (15) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN   08102017
# 1       NaN       NaN           NaN          NaN   12292017
# 2       NaN       NaN           NaN          NaN   09262017
# 3       NaN       NaN           NaN          NaN   11042017
# 4       NaN       NaN           NaN          NaN   02252018
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG
# 0        NaN      N
# 1        NaN      N
# 2        NaN      N
# 3        NaN      N
# 4        NaN      N

# %% [markdown]
# Check the data types of your columns to be sure! If you do it right they'll be `object` (not `str`, oddly).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 597816 entries, 0 to 597815
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LICTYPE         590730 non-null  object
#  1   LICNUMBER       597816 non-null  object
#  2   BIZCOUNTY       568035 non-null  object
#  3   BIZNAME         597815 non-null  object
#  4   BIZLINE1        0 non-null       float64
#  5   BIZLINE2        0 non-null       float64
#  6   BIZCITYSTATE    0 non-null       float64
#  7   BIZTELEPHONE    0 non-null       object
#  8   EXPIRATION      597816 non-null  object
#  9   OWNER           597805 non-null  object
#  10  MAILLINE1       541333 non-null  object
#  11  MAILLINE2       13863 non-null   object
#  12  MAILCITYSTATE   564578 non-null  object
#  13  MAILCOUNTYCODE  564869 non-null  object
#  14  MAILCOUNTY      592402 non-null  object
#  15  MAILZIP         597816 non-null  object
#  16  TELEPHONE       536224 non-null  object
#  17  LICSUBTYPE      579162 non-null  object
#  18  CEFLAG          594237 non-null  object
# dtypes: float64(3), object(16)
# memory usage: 86.7+ MB

# %%
df.dtypes
# Out:
# LICTYPE            object
# LICNUMBER          object
# BIZCOUNTY          object
# BIZNAME            object
# BIZLINE1          float64
# BIZLINE2          float64
# BIZCITYSTATE      float64
# BIZTELEPHONE       object
# EXPIRATION         object
# OWNER              object
# MAILLINE1          object
# MAILLINE2          object
# MAILCITYSTATE      object
# MAILCOUNTYCODE     object
# MAILCOUNTY         object
# MAILZIP            object
# TELEPHONE          object
# LICSUBTYPE         object
# CEFLAG             object
# dtype: object

# %%
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN   08102017
# 1       NaN       NaN           NaN          NaN   12292017
# 2       NaN       NaN           NaN          NaN   09262017
# 3       NaN       NaN           NaN          NaN   11042017
# 4       NaN       NaN           NaN          NaN   02252018
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG
# 0        NaN      N
# 1        NaN      N
# 2        NaN      N
# 3        NaN      N
# 4        NaN      N

# %% [markdown]
# ## 4. Convert those expiration dates from MMDDYYYY to YYYY-MM-DD
#
# You can use list slicing with `.str` (we did `dt.per_name.str[:4]` for the home data stuff once), `pd.to_datetime`, or a hundred other methods.

# %%
df['EXPIRATION']= pd.to_datetime(df['EXPIRATION'], format='%m%d%Y')

# %% [markdown]
# Check the first five expirations to make sure they look right.

# %%
#df.dtypes
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG
# 0        NaN      N
# 1        NaN      N
# 2        NaN      N
# 3        NaN      N
# 4        NaN      N

# %% [markdown]
# # PART TWO: LOOKING AT LICENSES

# %% [markdown]
# ## 5. What are the top 10 most common licenses?

# %%
df['LICTYPE'].value_counts().head(10)
# Out:
# Cosmetology Operator        151206
# Apprentice Electrician      110593
# Cosmetology Manicurist       49563
# Journeyman Electrician       38170
# A/C Technician               27959
# Cosmetology Esthetician      23613
# Cosmetology Beauty Salon     23577
# Master Electrician           16810
# A/C Contractor               16376
# Barber, Class A              16019
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 6. What are the top 10 least common?

# %%
df['LICTYPE'].value_counts().sort_values().head(10)
# Out:
# Legal Service Contract Admin                       1
# Mobile Cosmetology Esthetician/Manicure Saloon     2
# Cosmetology Wig Instructor                         2
# Mobile Cosmetology Manicure Specialty Saloon       2
# Licensed Court Interpreter CE Provider             2
# Booting CE Provider                                3
# Barber Hair Weaving Shop                           4
# Barber Hair Braiding Shop                          4
# Mobile Cosmetology Esthetician Specialty Saloon    5
# Registered Accessibility Specialist CE Provider    8
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 7. Try to select everyone who is any type of electrician.
#
# You're going to get an error about `"cannot index with vector containing NA / NaN values"`. Let's work our way in there.

# %%
# Yes I know I left this in here, it's a learning experience!
#df[df['LICTYPE'].str.contains("Electrician")]

# %% [markdown]
# ## 8. How many of the rows of LICTYPE are NaN?

# %%
df['LICTYPE'].isna().value_counts()
# Out:
# False    590730
# True       7086
# Name: LICTYPE, dtype: int64

# %% [markdown]
# Over 7000 licenses don't have types! As a result, when we look for license types with electricians - aka do `df['LICTYPE'].str.contains("Electrician")` - we get three results:
#
# * `True` means `LICTYPE` exists and contains `"Electrician"`
# * `False` means `LICTYPE` exists and does not contain `"Electrician"`
# * `NaN` means `LICTYPE` does not exist for that row

# %% [markdown]
# ## 9. Actually getting everyone who is an electrician

# %% [markdown]
# This doesn't work when trying to select electricians, though, as NaN is a no-go for a filter. We *could* filter out everywhere the LICTYPE is null, but we could also cheat a little and say "replace all of the `NaN` values with `False` values."
#
# `.fillna(False)` will take every `NaN` and replace it with `False`.

# %%
df['LICTYPE'] = df['LICTYPE'].fillna(False)

# %%
df['LICTYPE'].isna().value_counts()
# Out:
# False    597816
# Name: LICTYPE, dtype: int64

# %%
df['LICTYPE'] = df['LICTYPE'].astype(str)

# %% [markdown]
# ## 10. What's the most popular kind of electrician?

# %%
df['LICTYPE'][df['LICTYPE'].str.contains("Electrician")].value_counts()
# Out:
# Apprentice Electrician                110593
# Journeyman Electrician                 38170
# Master Electrician                     16810
# Apprentice Sign Electrician             3994
# Maintenance Electrician                 1184
# Master Sign Electrician                  542
# Journeyman Sign Electrician              391
# Electrician CE Provider                  109
# Electrician Apprenticeship Program        45
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 11. Graph it, with the largest bar on top.

# %%
df['LICTYPE'][df['LICTYPE'].str.contains("Electrician")].value_counts().sort_values().plot(
    kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 12. How many sign electricians are there?
#
# There are a few ways to do this one.

# %%
df['LICTYPE'][(df['LICTYPE'].str.contains("Electrician")) & (df['LICTYPE'].str.contains("Sign"))].value_counts()
# Out:
# Apprentice Sign Electrician    3994
# Master Sign Electrician         542
# Journeyman Sign Electrician     391
# Name: LICTYPE, dtype: int64

# %% [markdown]
# # PART THREE: LOOKING AT LAST NAMES

# %% [markdown]
# ## 13. Extract every owner's last name
#
# You want everything before the comma. We've done this before (in a few different ways!).
#
# * **Hint:** If you get an error about missing or `NaN` data, you might use `.fillna('')` to replace every empty owner name with an empty string. This might not happen to you, though, depending on how you do it!
#
# * **Hint:** You probably want to do `expand=False` on your extraction to make sure it comes out as a series instead of a dataframe.

# %%
df.head(13)
# Out:
#                  LICTYPE LICNUMBER     BIZCOUNTY                   BIZNAME  \
# 0   Associate Auctioneer      7326      ANGELINA      RISINGER, JIM MARVIN
# 1   Associate Auctioneer      7962        UPSHUR       WILLIAMS, JON ANDRE
# 2   Associate Auctioneer      8406        WILSON     GUEVARA, JUAN ANTONIO
# 3   Associate Auctioneer     10543        HARRIS  BOWERS, JAMES BRISCOE II
# 4   Associate Auctioneer     10642          BELL       DEMSKY, JOHN EDWARD
# 5   Associate Auctioneer     15650  OUT OF STATE         THOMPSON, RANDY D
# 6   Associate Auctioneer     15698  OUT OF STATE        TUCKER, MONTE EARL
# 7   Associate Auctioneer     15810         MILAM      COOPER, THOMAS JAMES
# 8   Associate Auctioneer     15835  OUT OF STATE   BLANKENSHIP, KERRY NEIL
# 9   Associate Auctioneer     16784  OUT OF STATE    DAWES, NICHOLAS MORGAN
# 10  Associate Auctioneer     16893         LAMAR      LESTER, TIMMY EUGENE
# 11  Associate Auctioneer     16969   NACOGDOCHES       MANCILL, MARK DUANE
# 12  Associate Auctioneer     16990         BEXAR    HUDDLESTON, SHAWN ALAN
#
#     BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0        NaN       NaN           NaN          NaN 2017-08-10
# 1        NaN       NaN           NaN          NaN 2017-12-29
# 2        NaN       NaN           NaN          NaN 2017-09-26
# 3        NaN       NaN           NaN          NaN 2017-11-04
# 4        NaN       NaN           NaN          NaN 2018-02-25
# 5        NaN       NaN           NaN          NaN 2017-05-04
# 6        NaN       NaN           NaN          NaN 2017-06-16
# 7        NaN       NaN           NaN          NaN 2017-03-18
# 8        NaN       NaN           NaN          NaN 2017-05-04
# 9        NaN       NaN           NaN          NaN 2017-10-19
# 10       NaN       NaN           NaN          NaN 2017-08-19
# 11       NaN       NaN           NaN          NaN 2017-04-21
# 12       NaN       NaN           NaN          NaN 2017-02-18
#
#                        OWNER                     MAILLINE1 MAILLINE2  \
# 0       RISINGER, JIM MARVIN              7668 S US HWY 59       NaN
# 1        WILLIAMS, JON ANDRE                   228 FM 1252       NaN
# 2      GUEVARA, JUAN ANTONIO                  6909 HWY 181       NaN
# 3   BOWERS, JAMES BRISCOE II                6767 NORTH FWY       NaN
# 4        DEMSKY, JOHN EDWARD                130 E CLARK ST       NaN
# 5          THOMPSON, RANDY D           10995 BELLEVILLE RD       NaN
# 6         TUCKER, MONTE EARL               19139 HIGHWAY 6       NaN
# 7       COOPER, THOMAS JAMES                   346 MAIN ST       NaN
# 8    BLANKENSHIP, KERRY NEIL           10664 BELLEVILLE RD       NaN
# 9     DAWES, NICHOLAS MORGAN  3500 MAPLE AVENUE 17TH FLOOR       NaN
# 10      LESTER, TIMMY EUGENE         167 COUNTY ROAD 16380       NaN
# 11       MANCILL, MARK DUANE             116 TRAILWOOD CIR       NaN
# 12    HUDDLESTON, SHAWN ALAN            3903 EISENHOUER RD       NaN
#
#              MAILCITYSTATE MAILCOUNTYCODE    MAILCOUNTY MAILZIP   TELEPHONE  \
# 0     NACOGDOCHES TX 75964           0347   NACOGDOCHES   75964  9363665745
# 1         KILGORE TX 75662           0183         GREGG   75662  9039187899
# 2            POTH TX 78147           0493        WILSON   78147         NaN
# 3    HOUSTON TX 77076-2027           0201        HARRIS   77076  7136445566
# 4        BARTLETT TX 76511           0027          BELL   76511  2549852228
# 5        RINGLING OK 73456           0999  OUT OF STATE   73456  5802765961
# 6      SAYRE OK 73662-6080           0999  OUT OF STATE   73662  5802250269
# 7         ROSEBUD TX 76570           0145         FALLS   76570  2815078713
# 8   RINGLING OK 73456-2014           0999  OUT OF STATE   73456  5802765961
# 9          DALLAS TX 75219           0113        DALLAS   75219  2144091137
# 10     CUNNINGHAM TX 75434           0277         LAMAR   75434  9037825759
# 11    LUFKIN TX 75904-4331           0005      ANGELINA   75904  9366749636
# 12    SAN ANTONIO TX 78218           0029         BEXAR   78218  2106815425
#
#    LICSUBTYPE CEFLAG
# 0         NaN      N
# 1         NaN      N
# 2         NaN      N
# 3         NaN      N
# 4         NaN      N
# 5         NaN      N
# 6         NaN      N
# 7         NaN      N
# 8         NaN      N
# 9         NaN      N
# 10        NaN      N
# 11        NaN      N
# 12        NaN      N

# %%
df['OWNER'].str.extract(r"(\w*),", expand=False)
# Out:
# 0         RISINGER
# 1         WILLIAMS
# 2          GUEVARA
# 3           BOWERS
# 4           DEMSKY
#             ...
# 597811        ABEL
# 597812        GRAY
# 597813       MAYER
# 597814     FRIESEN
# 597815       BAUER
# Name: OWNER, Length: 597816, dtype: object

# %% [markdown]
# ## 14. Save the last name into a new column
#
# Then check to make sure it exists, and you successfully saved it into the dataframe.

# %%
df['lastname'] = df['OWNER'].str.extract(r"(\w*),", expand=False)

# %%
#df.lastname.isna().value_counts()
#df[df.lastname.isna()]

# %% [markdown]
# # 15. What are the ten most popular last names?

# %%
df.lastname.value_counts().head(10)
# Out:
# NGUYEN       22321
# TRAN          8161
# GARCIA        5886
# LE            5616
# MARTINEZ      4936
# RODRIGUEZ     4869
# HERNANDEZ     4678
# PHAM          4009
# GONZALEZ      3844
#               3508
# Name: lastname, dtype: int64

# %% [markdown]
# ## 16. What are the most popular licenses for people with the last name Nguyen? Tran? Le?
#
# Those are the top 3 last names in Vietnam.

# %%
df['LICTYPE'][df.lastname =='NGUYEN'].value_counts().head()
# Out:
# Cosmetology Manicurist     12874
# Cosmetology Operator        4048
# Cosmetology Esthetician     2887
# Cosmetologist               1878
# Apprentice Electrician       195
# Name: LICTYPE, dtype: int64

# %%
df['LICTYPE'][df.lastname =='TRAN'].value_counts().head()
# Out:
# Cosmetology Manicurist     4686
# Cosmetology Operator       1481
# Cosmetology Esthetician    1034
# Cosmetologist               715
# Apprentice Electrician       96
# Name: LICTYPE, dtype: int64

# %%
df['LICTYPE'][df.lastname == 'LE'].value_counts().head()
# Out:
# Cosmetology Manicurist     3282
# Cosmetology Operator        954
# Cosmetology Esthetician     731
# Cosmetologist               500
# A/C Technician               43
# Name: LICTYPE, dtype: int64

# %% [markdown]
# The background of this [is interesting](https://www.npr.org/2019/05/19/724452398/how-vietnamese-americans-took-over-the-nails-business-a-documentary) and [tragic](https://www.nytimes.com/2015/05/10/nyregion/at-nail-salons-in-nyc-manicurists-are-underpaid-and-unprotected.html).

# %% [markdown]
# ## 17. Now do all of that in one line - most popular licenses for Nguyen, Tran and Le - without using `&`

# %%
df['LICTYPE'][df.lastname.isin(['NGUYEN','TRAN','LE'])].value_counts().head()
# Out:
# Cosmetology Manicurist     20842
# Cosmetology Operator        6483
# Cosmetology Esthetician     4652
# Cosmetologist               3093
# Apprentice Electrician       328
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 19. Most popular license for anyone with a last name that ENDS in `-ko`
#
# The answer is not `.str.contains('ko')`, but it isn't necessarily too different.
#
# * One way involves a `.str.` method that check if a string ends with something,
# * the other way involves a regular expression that has a "end of the string" marker (similar to how we've used `^` for the start of a string before)
#
# If you're thinking about the latter, I might take a look at [this page](http://www.rexegg.com/regex-quickstart.html) under "Anchors and Boundaries".

# %%
df.lastname = df.lastname.fillna('None')
df.lastname.isna().value_counts()
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER         MAILLINE1 MAILLINE2  \
# 0      RISINGER, JIM MARVIN  7668 S US HWY 59       NaN
# 1       WILLIAMS, JON ANDRE       228 FM 1252       NaN
# 2     GUEVARA, JUAN ANTONIO      6909 HWY 181       NaN
# 3  BOWERS, JAMES BRISCOE II    6767 NORTH FWY       NaN
# 4       DEMSKY, JOHN EDWARD    130 E CLARK ST       NaN
#
#            MAILCITYSTATE MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE  \
# 0   NACOGDOCHES TX 75964           0347  NACOGDOCHES   75964  9363665745
# 1       KILGORE TX 75662           0183        GREGG   75662  9039187899
# 2          POTH TX 78147           0493       WILSON   78147         NaN
# 3  HOUSTON TX 77076-2027           0201       HARRIS   77076  7136445566
# 4      BARTLETT TX 76511           0027         BELL   76511  2549852228
#
#   LICSUBTYPE CEFLAG  lastname
# 0        NaN      N  RISINGER
# 1        NaN      N  WILLIAMS
# 2        NaN      N   GUEVARA
# 3        NaN      N    BOWERS
# 4        NaN      N    DEMSKY

# %%
df[df['lastname'].str.match(r".*KO$")]
# Out:
#                                              LICTYPE LICNUMBER BIZCOUNTY  \
# 6007                                  A/C Technician     20195     BOWIE
# 6069                                  A/C Technician     20410    DALLAS
# 8187                                  A/C Technician     29043    HARRIS
# 9865                                  A/C Technician     37165    TRAVIS
# 12275                                 A/C Technician     47111    TRAVIS
# ...                                              ...       ...       ...
# 580675      Tow Truck Operator (Incident Management)     36058  MCLENNAN
# 582866      Tow Truck Operator (Incident Management)     38909    DALLAS
# 588181                        Property Tax Appraiser     74632       NaN
# 591562             Used Auto Parts Recycler Employee      4857    DALLAS
# 596043  Water Well Driller/Pump Installer Apprentice     59914   TARRANT
#
#                     BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE  \
# 6007        KOKKO, ROBERT J       NaN       NaN           NaN          NaN
# 6069      TSALKO, ALEXANDRE       NaN       NaN           NaN          NaN
# 8187         ELASKO, JOHN P       NaN       NaN           NaN          NaN
# 9865    PIEKIELKO, JOSEPH E       NaN       NaN           NaN          NaN
# 12275       METKO, JOSEPH C       NaN       NaN           NaN          NaN
# ...                     ...       ...       ...           ...          ...
# 580675       LUCKO, DYLAN L       NaN       NaN           NaN          NaN
# 582866      ARKO, BRANDON T       NaN       NaN           NaN          NaN
# 588181  DZURKO, LINDA STARR       NaN       NaN           NaN          NaN
# 591562    SHEYKO, MIKHAIL S       NaN       NaN           NaN          NaN
# 596043    PETKO, KYLE ROGER       NaN       NaN           NaN          NaN
#
#        EXPIRATION                OWNER            MAILLINE1 MAILLINE2  \
# 6007   2017-05-04      KOKKO, ROBERT J                  NaN       NaN
# 6069   2017-04-27    TSALKO, ALEXANDRE                  NaN       NaN
# 8187   2017-09-21       ELASKO, JOHN P                  NaN       NaN
# 9865   2017-04-05  PIEKIELKO, JOSEPH E                  NaN       NaN
# 12275  2017-09-28      METKO, JOSEPH C                  NaN       NaN
# ...           ...                  ...                  ...       ...
# 580675 2016-09-04       LUCKO, DYLAN L                  NaN       NaN
# 582866 2017-05-16      ARKO, BRANDON T                  NaN       NaN
# 588181 2017-11-07  DZURKO, LINDA STARR   5801 TROWBRIDGE DR       NaN
# 591562 2017-07-23    SHEYKO, MIKHAIL S  14750 STATE HWY 205       NaN
# 596043 2017-12-29    PETKO, KYLE ROGER       6813 HALTOM RD       NaN
#
#                    MAILCITYSTATE MAILCOUNTYCODE MAILCOUNTY MAILZIP  \
# 6007                         NaN            NaN      BOWIE   75569
# 6069                         NaN            NaN     DALLAS   75089
# 8187                         NaN            NaN     HARRIS   77336
# 9865                         NaN            NaN     TRAVIS   78617
# 12275                        NaN            NaN     TRAVIS   78725
# ...                          ...            ...        ...     ...
# 580675                      WACO           0309   MCLENNAN   76705
# 582866                     PLANO           0085     COLLIN   75075
# 588181          EL PASO TX 79925           0141    EL PASO   79925
# 591562          TERRELL TX 75160           0257    KAUFMAN   75160
# 596043  FORT WORTH TX 76137-2351           0439    TARRANT   76137
#
#          TELEPHONE LICSUBTYPE CEFLAG   lastname
# 6007           NaN        REG      N      KOKKO
# 6069           NaN        REG      N     TSALKO
# 8187           NaN        REG      N     ELASKO
# 9865           NaN        REG      N  PIEKIELKO
# 12275          NaN        REG      N      METKO
# ...            ...        ...    ...        ...
# 580675         NaN         IM      N      LUCKO
# 582866         NaN         IM      N       ARKO
# 588181  9157802000  APPRAISER      N     DZURKO
# 591562         NaN   EMPLOYEE      N     SHEYKO
# 596043         NaN        NaN      N      PETKO
#
# [180 rows x 20 columns]

# %%
df['LICTYPE'][df['lastname'].str.match(r".*KO$")].value_counts().head(1)
# Out:
# Cosmetology Operator    67
# Name: LICTYPE, dtype: int64

# %%
#df['LICTYPE'][df.lastname.(r".*ko$")]

# %% [markdown]
# ## 20. Get that as a percentage

# %%
df['LICTYPE'][df['lastname'].str.match(r".*KO$")].value_counts(normalize=True).head(1)*100
# Out:
# Cosmetology Operator    37.222222
# Name: LICTYPE, dtype: float64

# %% [markdown]
# # PART FOUR: LOOKING AT FIRST NAMES

# %% [markdown]
# ## 21. Extract the owner's first name
#
# First, a little example of how regular expressions work with pandas.

# %%
# Build a dataframe
sample_df = pd.DataFrame([
    { 'name': 'Mary', 'sentence': "I am 90 years old" },
    { 'name': 'Jack', 'sentence': "I am 4 years old" },
    { 'name': 'Anne', 'sentence': "I am 27 years old" },
    { 'name': 'Joel', 'sentence': "I am 13 years old" },
])
# Look at the dataframe
sample_df
# Out:
#    name           sentence
# 0  Mary  I am 90 years old
# 1  Jack   I am 4 years old
# 2  Anne  I am 27 years old
# 3  Joel  I am 13 years old

# %%
# Given the sentence, "I am X years old", extract digits from the middle using ()
# Anything you put in () will be saved as an output.
# If you do expand=True it makes you a dataframe, but we don't want that.
sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
# Out:
# 0    90
# 1     4
# 2    27
# 3    13
# Name: sentence, dtype: object

# %%
# Save it into a new column
sample_df['age'] = sample_df['sentence'].str.extract("I am (\d+) years old", expand=False)
sample_df.head()
# Out:
#    name           sentence age
# 0  Mary  I am 90 years old  90
# 1  Jack   I am 4 years old   4
# 2  Anne  I am 27 years old  27
# 3  Joel  I am 13 years old  13

# %% [markdown]
# **Now let's think about how we're going to extract the first names.** Begin by looking at a few full names.

# %%
df['OWNER'].head(12)
# Out:
# 0         RISINGER, JIM MARVIN
# 1          WILLIAMS, JON ANDRE
# 2        GUEVARA, JUAN ANTONIO
# 3     BOWERS, JAMES BRISCOE II
# 4          DEMSKY, JOHN EDWARD
# 5            THOMPSON, RANDY D
# 6           TUCKER, MONTE EARL
# 7         COOPER, THOMAS JAMES
# 8      BLANKENSHIP, KERRY NEIL
# 9       DAWES, NICHOLAS MORGAN
# 10        LESTER, TIMMY EUGENE
# 11         MANCILL, MARK DUANE
# Name: OWNER, dtype: object

# %% [markdown]
# What can you use to find the first name? It helps to say "this is to the left and this is to the right, and I'm going to take anything in the middle."
#
# Once you figure out how to extract it, you can do a `.head(10)` to just look at the first few.

# %%
#df['OWNER'].str.extract(r",\s?([\w\W\s]*)$").head(10)
df['OWNER'].str.extract(r",\s?(\w*)[\W\w]*$").head(10)
# Out:
#           0
# 0       JIM
# 1       JON
# 2      JUAN
# 3     JAMES
# 4      JOHN
# 5     RANDY
# 6     MONTE
# 7    THOMAS
# 8     KERRY
# 9  NICHOLAS

# %% [markdown]
# ## 22. Saving the owner's first name
#
# Save the name to a new column, `FIRSTNAME`.

# %%
df['FIRSTNAME'] = df['OWNER'].str.extract(r",\s?(\w*)[\W\w]*$")
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER  ... MAILLINE2          MAILCITYSTATE  \
# 0      RISINGER, JIM MARVIN  ...       NaN   NACOGDOCHES TX 75964
# 1       WILLIAMS, JON ANDRE  ...       NaN       KILGORE TX 75662
# 2     GUEVARA, JUAN ANTONIO  ...       NaN          POTH TX 78147
# 3  BOWERS, JAMES BRISCOE II  ...       NaN  HOUSTON TX 77076-2027
# 4       DEMSKY, JOHN EDWARD  ...       NaN      BARTLETT TX 76511
#
#   MAILCOUNTYCODE   MAILCOUNTY MAILZIP   TELEPHONE LICSUBTYPE CEFLAG  lastname  \
# 0           0347  NACOGDOCHES   75964  9363665745        NaN      N  RISINGER
# 1           0183        GREGG   75662  9039187899        NaN      N  WILLIAMS
# 2           0493       WILSON   78147         NaN        NaN      N   GUEVARA
# 3           0201       HARRIS   77076  7136445566        NaN      N    BOWERS
# 4           0027         BELL   76511  2549852228        NaN      N    DEMSKY
#
#   FIRSTNAME
# 0       JIM
# 1       JON
# 2      JUAN
# 3     JAMES
# 4      JOHN
#
# [5 rows x 21 columns]

# %% [markdown]
# # 23. Examine everyone without a first name
#
# I purposefully didn't do a nicer regex in order to have some screwed-up results. **How many people are there without an entry in the first name column?**
#
# Your numbers might be different than mine.

# %%
df.FIRSTNAME.isna().value_counts()
# Out:
# False    516215
# True      81601
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# What do their names look like?

# %%
df[df.FIRSTNAME.isna()]
# Out:
#                                   LICTYPE LICNUMBER  BIZCOUNTY  \
# 28022   Appliance Installation Contractor       101     HARRIS
# 28023   Appliance Installation Contractor       103     DALLAS
# 28024   Appliance Installation Contractor       104     DALLAS
# 28025   Appliance Installation Contractor       107      BOWIE
# 28026   Appliance Installation Contractor       108  FREESTONE
# ...                                   ...       ...        ...
# 590395           Used Auto Parts Recycler      1513      BEXAR
# 590397           Used Auto Parts Recycler      1514     DALLAS
# 590399           Used Auto Parts Recycler      1515     HARRIS
# 590400           Used Auto Parts Recycler      1516     DALLAS
# 590401           Used Auto Parts Recycler      1517    TARRANT
#
#                                         BIZNAME  BIZLINE1  BIZLINE2  \
# 28022   APPLIANCE INSTALLATION BY SPECIAL D LLC       NaN       NaN
# 28023                  CAPITAL DISTRIBUTING INC       NaN       NaN
# 28024                             INSTALLCO LLC       NaN       NaN
# 28025              LAFFERTYS TV & APPLIANCE INC       NaN       NaN
# 28026                           BALLARD COMPANY       NaN       NaN
# ...                                         ...       ...       ...
# 590395                         R & D PARTS INC.       NaN       NaN
# 590397                   DFW AUTO & PARTS SALES       NaN       NaN
# 590399             T&D BRADLEY AUTO SERVICE LLC       NaN       NaN
# 590400                         A & M AUTO PARTS       NaN       NaN
# 590401                  STEVENS CORE SUPPLY INC       NaN       NaN
#
#         BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 28022            NaN          NaN 2017-05-23
# 28023            NaN          NaN 2017-04-08
# 28024            NaN          NaN 2017-04-08
# 28025            NaN          NaN 2018-03-20
# 28026            NaN          NaN 2017-04-02
# ...              ...          ...        ...
# 590395           NaN          NaN 2018-02-16
# 590397           NaN          NaN 2018-02-24
# 590399           NaN          NaN 2018-02-24
# 590400           NaN          NaN 2018-02-28
# 590401           NaN          NaN 2018-03-01
#
#                                           OWNER  ... MAILLINE2  \
# 28022   APPLIANCE INSTALLATION BY SPECIAL D LLC  ...       NaN
# 28023                  CAPITAL DISTRIBUTING INC  ...       NaN
# 28024                             INSTALLCO LLC  ...       NaN
# 28025              LAFFERTYS TV & APPLIANCE INC  ...       NaN
# 28026                           BALLARD COMPANY  ...       NaN
# ...                                         ...  ...       ...
# 590395                         R & D PARTS INC.  ...       NaN
# 590397                   DFW AUTO & PARTS SALES  ...       NaN
# 590399             T&D BRADLEY AUTO SERVICE LLC  ...       NaN
# 590400                         A & M AUTO PARTS  ...       NaN
# 590401                  STEVENS CORE SUPPLY INC  ...       NaN
#
#                 MAILCITYSTATE MAILCOUNTYCODE MAILCOUNTY MAILZIP   TELEPHONE  \
# 28022        HOUSTON TX 77093           0201     HARRIS   77093  2815363711
# 28023    DALLAS TX 75247-6103           0113     DALLAS   75247  2146382681
# 28024    DALLAS TX 75247-6103           0113     DALLAS   75247  2142761033
# 28025      TEXARKANA TX 75503           0037      BOWIE   75503  9037942581
# 28026      FAIRFIELD TX 75840           0161  FREESTONE   75840  9033895774
# ...                       ...            ...        ...     ...         ...
# 590395   SAN ANTONIO TX 78211           0029      BEXAR   78211  2106232000
# 590397   HALTOM CITY TX 76117           0439    TARRANT   76117  8174399281
# 590399  HOUSTON TX 77022-6106           0201     HARRIS   77022  8322096210
# 590400   DALLAS TX 75216-4138           0113     DALLAS   75216  2143711500
# 590401   SANSOM PARK TX 76114           0439    TARRANT   76114  8173329820
#
#        LICSUBTYPE CEFLAG lastname FIRSTNAME
# 28022        RAIC      N     None       NaN
# 28023        RAIC      N     None       NaN
# 28024        RAIC      N     None       NaN
# 28025        RAIC      N     None       NaN
# 28026        RAIC      N     None       NaN
# ...           ...    ...      ...       ...
# 590395   RECYCLER      N     None       NaN
# 590397   RECYCLER      N     None       NaN
# 590399   RECYCLER      N     None       NaN
# 590400   RECYCLER      N     None       NaN
# 590401   RECYCLER      N     None       NaN
#
# [81601 rows x 21 columns]

# %% [markdown]
# ## 24. If it's a problem, you can fix it (if you'd like!)
#
# Maybe you have another regular expression that works better with JUST these people? It really depends on how you've put together your previous regex!
#
# If you'd like to use a separate regex for this group, you can use code like this:
#
# `df.loc[df.FIRSTNAME.isnull(), 'FIRSTNAME'] = .....`
#
# That will only set the `FIRSTNAME` for people where `FIRSTNAME` is null.

# %%
#I'm confused... It seems most of the missing first names are because the owner's name is listed as a company. 
# Should the regex change to include them??

# %%
#These are some common problems/still-dirty things I noticed in the data. There could be more I am not sure how to remove them

# %%
df[df.FIRSTNAME == 'INC']
# Out:
#                                   LICTYPE LICNUMBER     BIZCOUNTY  \
# 28021   Appliance Installation Contractor       100        TRAVIS
# 28029   Appliance Installation Contractor       113  OUT OF STATE
# 28056   Appliance Installation Contractor       171  OUT OF STATE
# 28057   Appliance Installation Contractor       174        HARRIS
# 28066   Appliance Installation Contractor       192        NUECES
# ...                                   ...       ...           ...
# 590169           Used Auto Parts Recycler      1336        HARRIS
# 590186           Used Auto Parts Recycler      1357          HAYS
# 590235           Used Auto Parts Recycler      1401       CAMERON
# 590254           Used Auto Parts Recycler      1418       GRAYSON
# 590341           Used Auto Parts Recycler      1475        DALLAS
#
#                                   BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 28021   OBY'S APPLIANCE INSTALLATION, INC       NaN       NaN           NaN
# 28029                 HOME DEPOT USA, INC       NaN       NaN           NaN
# 28056           J.B. HUNT TRANSPORT, INC.       NaN       NaN           NaN
# 28057                          DUPAR, INC       NaN       NaN           NaN
# 28066            RAY WEST WAREHOUSES, INC       NaN       NaN           NaN
# ...                                   ...       ...       ...           ...
# 590169       ESTRELLA USED PARTS #5, INC.       NaN       NaN           NaN
# 590186                       CHMEIS, INC.       NaN       NaN           NaN
# 590235         ROLANDO GARZA MOTORS, INC.       NaN       NaN           NaN
# 590254           ELLIS TRUCK & AUTO, INC.       NaN       NaN           NaN
# 590341              MID-WEST ENGINE, INC.       NaN       NaN           NaN
#
#        BIZTELEPHONE EXPIRATION                              OWNER  ...  \
# 28021           NaN 2018-02-28  OBY'S APPLIANCE INSTALLATION, INC  ...
# 28029           NaN 2018-04-11                HOME DEPOT USA, INC  ...
# 28056           NaN 2017-06-24          J.B. HUNT TRANSPORT, INC.  ...
# 28057           NaN 2017-06-29                         DUPAR, INC  ...
# 28066           NaN 2017-08-27           RAY WEST WAREHOUSES, INC  ...
# ...             ...        ...                                ...  ...
# 590169          NaN 2018-01-20       ESTRELLA USED PARTS #5, INC.  ...
# 590186          NaN 2017-05-18                       CHMEIS, INC.  ...
# 590235          NaN 2016-12-02         ROLANDO GARZA MOTORS, INC.  ...
# 590254          NaN 2017-02-18           ELLIS TRUCK & AUTO, INC.  ...
# 590341          NaN 2017-09-08              MID-WEST ENGINE, INC.  ...
#
#                        MAILLINE2                 MAILCITYSTATE MAILCOUNTYCODE  \
# 28021                        NaN               AUSTIN TX 78757           0453
# 28029   C11 HOME SVCS COMPLIANCE              ATLANTA GA 30339           0999
# 28056                        NaN          LOWELL AR 72745-0598           0999
# 28057                        NaN              HOUSTON TX 77064           0201
# 28066                        NaN  CORPUS CHRISTI TX 78408-2744           0355
# ...                          ...                           ...            ...
# 590169                       NaN           HUNTSVILLE TX 77320           0471
# 590186                       NaN                 KYLE TX 78640           0209
# 590235                       NaN          BROWNSVILLE TX 78521           0061
# 590254                       NaN              SHERMAN TX 75092           0181
# 590341                       NaN           SEAGOVILLE TX 75159           0113
#
#           MAILCOUNTY MAILZIP   TELEPHONE LICSUBTYPE CEFLAG      lastname  \
# 28021         TRAVIS   78757  5124540550       RAIC      N  INSTALLATION
# 28029   OUT OF STATE   30339  9728720128       RAIC      N           USA
# 28056   OUT OF STATE   72745  4794193157       RAIC      N     TRANSPORT
# 28057         HARRIS   77064  2815172300       RAIC      N         DUPAR
# 28066         NUECES   78408  3618845595       RAIC      N    WAREHOUSES
# ...              ...     ...         ...        ...    ...           ...
# 590169        WALKER   77320  9362940399   RECYCLER      N             5
# 590186          HAYS   78640  5122950086   RECYCLER      N        CHMEIS
# 590235       CAMERON   78521  9565044040   RECYCLER      N        MOTORS
# 590254       GRAYSON   75092  9038931127   RECYCLER      N          AUTO
# 590341        DALLAS   75159  2149481590   RECYCLER      N        ENGINE
#
#        FIRSTNAME
# 28021        INC
# 28029        INC
# 28056        INC
# 28057        INC
# 28066        INC
# ...          ...
# 590169       INC
# 590186       INC
# 590235       INC
# 590254       INC
# 590341       INC
#
# [1077 rows x 21 columns]

# %%
df[df.FIRSTNAME == 'LLC']
# Out:
#                                   LICTYPE LICNUMBER BIZCOUNTY  \
# 28061   Appliance Installation Contractor       182    TRAVIS
# 28128   Appliance Installation Contractor       273    DALLAS
# 28290   Appliance Installation Contractor       472   TARRANT
# 28337   Appliance Installation Contractor       531    PARKER
# 28373   Appliance Installation Contractor       578    BRAZOS
# ...                                   ...       ...       ...
# 590263           Used Auto Parts Recycler      1424    DALLAS
# 590270           Used Auto Parts Recycler      1429    DALLAS
# 590304           Used Auto Parts Recycler      1452    HARRIS
# 590321           Used Auto Parts Recycler      1463   CAMERON
# 590393           Used Auto Parts Recycler      1512    HARRIS
#
#                                BIZNAME  BIZLINE1  BIZLINE2  BIZCITYSTATE  \
# 28061   LONGHORN DELIVERY SERVICE, LLC       NaN       NaN           NaN
# 28128     TEXAN BLUE POOL SERVICE, LLC       NaN       NaN           NaN
# 28290         CONNOR POOL SERVICE, LLC       NaN       NaN           NaN
# 28337             ECO-SMART POOLS, LLC       NaN       NaN           NaN
# 28373    THE POOL GUY ENTERPRISES, LLC       NaN       NaN           NaN
# ...                                ...       ...       ...           ...
# 590263   US TRUCK PARTS AND SALES, LLC       NaN       NaN           NaN
# 590270      TX ORIGINAL CAR AUDIO, LLC       NaN       NaN           NaN
# 590304      MAX TRUCK & EQUIPMENT, LLC       NaN       NaN           NaN
# 590321             RANCHO AUTOPLEX,LLC       NaN       NaN           NaN
# 590393       BASIR AUTO RECYCLING, LLC       NaN       NaN           NaN
#
#        BIZTELEPHONE EXPIRATION                           OWNER  ... MAILLINE2  \
# 28061           NaN 2016-02-03  LONGHORN DELIVERY SERVICE, LLC  ...       NaN
# 28128           NaN 2017-07-13    TEXAN BLUE POOL SERVICE, LLC  ...       NaN
# 28290           NaN 2017-04-26        CONNOR POOL SERVICE, LLC  ...       NaN
# 28337           NaN 2018-02-08            ECO-SMART POOLS, LLC  ...       NaN
# 28373           NaN 2018-04-16   THE POOL GUY ENTERPRISES, LLC  ...       NaN
# ...             ...        ...                             ...  ...       ...
# 590263          NaN 2018-03-14   US TRUCK PARTS AND SALES, LLC  ...       NaN
# 590270          NaN 2017-03-23      TX ORIGINAL CAR AUDIO, LLC  ...       NaN
# 590304          NaN 2017-07-13      MAX TRUCK & EQUIPMENT, LLC  ...       NaN
# 590321          NaN 2017-08-15             RANCHO AUTOPLEX,LLC  ...       NaN
# 590393          NaN 2018-02-09       BASIR AUTO RECYCLING, LLC  ...       NaN
#
#                    MAILCITYSTATE MAILCOUNTYCODE MAILCOUNTY MAILZIP  \
# 28061            AUSTIN TX 78748           0453     TRAVIS   78748
# 28128    FARMERS BRANCH TX 75229           0113     DALLAS   75229
# 28290   FORT WORTH TX 76115-3143           0439    TARRANT   76115
# 28337        ALEDO TX 76008-3061           0367     PARKER   76008
# 28373   COLLEGE STATION TX 77845           0041     BRAZOS   77845
# ...                          ...            ...        ...     ...
# 590263           DALLAS TX 75253           0113     DALLAS   75253
# 590270       RICHARDSON TX 75081           0113     DALLAS   75081
# 590304          HOUSTON TX 77028           0201     HARRIS   77028
# 590321      BROWNSVILLE TX 78520           0061    CAMERON   78520
# 590393     HOUSTON TX 77047-3744           0201     HARRIS   77047
#
#          TELEPHONE LICSUBTYPE CEFLAG     lastname FIRSTNAME
# 28061   5122030906       RAIC      N      SERVICE       LLC
# 28128   8179857665       RAIC      N      SERVICE       LLC
# 28290   8176142546       RAIC      N      SERVICE       LLC
# 28337   8173190654       RAIC      N        POOLS       LLC
# 28373   9795756200       RAIC      N  ENTERPRISES       LLC
# ...            ...        ...    ...          ...       ...
# 590263  9725577979   RECYCLER      N        SALES       LLC
# 590270  2145755635   RECYCLER      N        AUDIO       LLC
# 590304  7136353433   RECYCLER      N    EQUIPMENT       LLC
# 590321  9562804457   RECYCLER      N     AUTOPLEX       LLC
# 590393  7137341621   RECYCLER      N    RECYCLING       LLC
#
# [732 rows x 21 columns]

# %% [markdown]
# How many empty first names do we have now?

# %%
df[df.lastname == 'None']
# Out:
#                                   LICTYPE LICNUMBER  BIZCOUNTY  \
# 28022   Appliance Installation Contractor       101     HARRIS
# 28023   Appliance Installation Contractor       103     DALLAS
# 28024   Appliance Installation Contractor       104     DALLAS
# 28025   Appliance Installation Contractor       107      BOWIE
# 28026   Appliance Installation Contractor       108  FREESTONE
# ...                                   ...       ...        ...
# 590395           Used Auto Parts Recycler      1513      BEXAR
# 590397           Used Auto Parts Recycler      1514     DALLAS
# 590399           Used Auto Parts Recycler      1515     HARRIS
# 590400           Used Auto Parts Recycler      1516     DALLAS
# 590401           Used Auto Parts Recycler      1517    TARRANT
#
#                                         BIZNAME  BIZLINE1  BIZLINE2  \
# 28022   APPLIANCE INSTALLATION BY SPECIAL D LLC       NaN       NaN
# 28023                  CAPITAL DISTRIBUTING INC       NaN       NaN
# 28024                             INSTALLCO LLC       NaN       NaN
# 28025              LAFFERTYS TV & APPLIANCE INC       NaN       NaN
# 28026                           BALLARD COMPANY       NaN       NaN
# ...                                         ...       ...       ...
# 590395                         R & D PARTS INC.       NaN       NaN
# 590397                   DFW AUTO & PARTS SALES       NaN       NaN
# 590399             T&D BRADLEY AUTO SERVICE LLC       NaN       NaN
# 590400                         A & M AUTO PARTS       NaN       NaN
# 590401                  STEVENS CORE SUPPLY INC       NaN       NaN
#
#         BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 28022            NaN          NaN 2017-05-23
# 28023            NaN          NaN 2017-04-08
# 28024            NaN          NaN 2017-04-08
# 28025            NaN          NaN 2018-03-20
# 28026            NaN          NaN 2017-04-02
# ...              ...          ...        ...
# 590395           NaN          NaN 2018-02-16
# 590397           NaN          NaN 2018-02-24
# 590399           NaN          NaN 2018-02-24
# 590400           NaN          NaN 2018-02-28
# 590401           NaN          NaN 2018-03-01
#
#                                           OWNER  ... MAILLINE2  \
# 28022   APPLIANCE INSTALLATION BY SPECIAL D LLC  ...       NaN
# 28023                  CAPITAL DISTRIBUTING INC  ...       NaN
# 28024                             INSTALLCO LLC  ...       NaN
# 28025              LAFFERTYS TV & APPLIANCE INC  ...       NaN
# 28026                           BALLARD COMPANY  ...       NaN
# ...                                         ...  ...       ...
# 590395                         R & D PARTS INC.  ...       NaN
# 590397                   DFW AUTO & PARTS SALES  ...       NaN
# 590399             T&D BRADLEY AUTO SERVICE LLC  ...       NaN
# 590400                         A & M AUTO PARTS  ...       NaN
# 590401                  STEVENS CORE SUPPLY INC  ...       NaN
#
#                 MAILCITYSTATE MAILCOUNTYCODE MAILCOUNTY MAILZIP   TELEPHONE  \
# 28022        HOUSTON TX 77093           0201     HARRIS   77093  2815363711
# 28023    DALLAS TX 75247-6103           0113     DALLAS   75247  2146382681
# 28024    DALLAS TX 75247-6103           0113     DALLAS   75247  2142761033
# 28025      TEXARKANA TX 75503           0037      BOWIE   75503  9037942581
# 28026      FAIRFIELD TX 75840           0161  FREESTONE   75840  9033895774
# ...                       ...            ...        ...     ...         ...
# 590395   SAN ANTONIO TX 78211           0029      BEXAR   78211  2106232000
# 590397   HALTOM CITY TX 76117           0439    TARRANT   76117  8174399281
# 590399  HOUSTON TX 77022-6106           0201     HARRIS   77022  8322096210
# 590400   DALLAS TX 75216-4138           0113     DALLAS   75216  2143711500
# 590401   SANSOM PARK TX 76114           0439    TARRANT   76114  8173329820
#
#        LICSUBTYPE CEFLAG lastname FIRSTNAME
# 28022        RAIC      N     None       NaN
# 28023        RAIC      N     None       NaN
# 28024        RAIC      N     None       NaN
# 28025        RAIC      N     None       NaN
# 28026        RAIC      N     None       NaN
# ...           ...    ...      ...       ...
# 590395   RECYCLER      N     None       NaN
# 590397   RECYCLER      N     None       NaN
# 590399   RECYCLER      N     None       NaN
# 590400   RECYCLER      N     None       NaN
# 590401   RECYCLER      N     None       NaN
#
# [81601 rows x 21 columns]

# %%
df[df.FIRSTNAME == 'CO']
# Out:
#                         LICTYPE LICNUMBER     BIZCOUNTY              BIZNAME  \
# 13211            A/C Technician     50554        HARRIS         LAO, CO KIEN
# 235113   Cosmetology Manicurist   1101678        NUECES           VU, CO THI
# 238814   Cosmetology Manicurist   1121040       TARRANT         TRAN, CO THI
# 242925   Cosmetology Manicurist   1141587        DALLAS  NGUYEN, CO HONG THI
# 273469  Cosmetology Esthetician   1254796        HARRIS   TRAN, CO THI TRIEU
# 276857   Cosmetology Manicurist   1265358        HARRIS   TRAN, CO THI TRIEU
# 291329   Cosmetology Manicurist   1312050        DALLAS        HUYNH, CO TAN
# 300907  Cosmetology Esthetician   1342140        DALLAS  NGUYEN, CO HONG THI
# 317615   Cosmetology Manicurist   1439427        HARRIS             TRAN, CO
# 340165   Cosmetology Manicurist   1498640        DALLAS       NGUYEN, CO THI
# 343005  Cosmetology Esthetician   1505447        HARRIS             TRAN, CO
# 344202   Cosmetology Manicurist   1508638  OUT OF STATE         PHAN, CO TAY
# 347723   Cosmetology Manicurist   1519171  OUT OF STATE             HA, CO T
# 363887            Cosmetologist   1559956       TARRANT         TRAN, CO THI
# 376877   Cosmetology Manicurist   1590371     GALVESTON            MAI, CO V
# 377562   Cosmetology Manicurist   1591777        HARRIS           LE, CO THI
# 377682   Cosmetology Manicurist   1592053        DALLAS            DAO, CO D
# 378177   Cosmetology Manicurist   1593124  OUT OF STATE          THACH, CO B
# 388524   Cosmetology Manicurist   1615952        HARRIS     HUYNH, CO THI MY
# 389186   Cosmetology Manicurist   1617396        DENTON         TRAN, CO THI
# 412310            Cosmetologist   1664688        HARRIS           DANG, CO T
# 423101   Cosmetology Manicurist   1692717        HARRIS   PHAM, CO DUYEN THI
# 430516            Cosmetologist   1723539        DALLAS  NGUYEN, CO HONG THI
# 481086    Electrical Contractor     22327           NaN      RV ELECTRIC, CO
# 481262    Electrical Contractor     22647           NaN  EXCEL ELECTRIC, CO.
#
#         BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 13211        NaN       NaN           NaN          NaN 2018-01-02
# 235113       NaN       NaN           NaN          NaN 2018-03-31
# 238814       NaN       NaN           NaN          NaN 2019-03-09
# 242925       NaN       NaN           NaN          NaN 2018-12-05
# 273469       NaN       NaN           NaN          NaN 2017-07-31
# 276857       NaN       NaN           NaN          NaN 2017-07-31
# 291329       NaN       NaN           NaN          NaN 2019-01-26
# 300907       NaN       NaN           NaN          NaN 2017-01-13
# 317615       NaN       NaN           NaN          NaN 2018-08-07
# 340165       NaN       NaN           NaN          NaN 2018-05-19
# 343005       NaN       NaN           NaN          NaN 2018-03-01
# 344202       NaN       NaN           NaN          NaN 2019-02-17
# 347723       NaN       NaN           NaN          NaN 2017-04-20
# 363887       NaN       NaN           NaN          NaN 2018-03-09
# 376877       NaN       NaN           NaN          NaN 2017-06-19
# 377562       NaN       NaN           NaN          NaN 2017-08-27
# 377682       NaN       NaN           NaN          NaN 2018-01-03
# 378177       NaN       NaN           NaN          NaN 2017-08-18
# 388524       NaN       NaN           NaN          NaN 2018-04-09
# 389186       NaN       NaN           NaN          NaN 2017-05-11
# 412310       NaN       NaN           NaN          NaN 2017-04-27
# 423101       NaN       NaN           NaN          NaN 2019-01-04
# 430516       NaN       NaN           NaN          NaN 2018-12-27
# 481086       NaN       NaN           NaN          NaN 2016-06-22
# 481262       NaN       NaN           NaN          NaN 2017-09-13
#
#                       OWNER  ... MAILLINE2                 MAILCITYSTATE  \
# 13211          LAO, CO KIEN  ...       NaN                           NaN
# 235113           VU, CO THI  ...       NaN  CORPUS CHRISTI TX 78413-5163
# 238814         TRAN, CO THI  ...       NaN       ARLINGTON TX 76014-3431
# 242925  NGUYEN, CO HONG THI  ...       NaN         GARLAND TX 75040-2701
# 273469   TRAN, CO THI TRIEU  ...       NaN         HOUSTON TX 77064-5194
# 276857   TRAN, CO THI TRIEU  ...       NaN         HOUSTON TX 77064-5194
# 291329        HUYNH, CO TAN  ...       NaN      CARROLLTON TX 75006-3169
# 300907  NGUYEN, CO HONG THI  ...       NaN         GARLAND TX 75040-2701
# 317615             TRAN, CO  ...       NaN         HOUSTON TX 77036-3525
# 340165       NGUYEN, CO THI  ...       NaN   GRAND PRAIRIE TX 75052-0736
# 343005             TRAN, CO  ...       NaN         HOUSTON TX 77057-5641
# 344202         PHAN, CO TAY  ...       NaN       SAN DIEGO CA 92105-1812
# 347723             HA, CO T  ...       NaN          HAMDEN CT 6514 -5121
# 363887         TRAN, CO THI  ...       NaN       ARLINGTON TX 76014-3431
# 376877            MAI, CO V  ...       NaN         BACLIFF TX 77518-2511
# 377562           LE, CO THI  ...       NaN         HOUSTON TX 77034-4643
# 377682            DAO, CO D  ...       NaN          DALLAS TX 75244-6603
# 378177          THACH, CO B  ...       NaN   OKLAHOMA CITY OK 73162-1093
# 388524     HUYNH, CO THI MY  ...       NaN         HOUSTON TX 77072-2143
# 389186         TRAN, CO THI  ...       NaN      CARROLLTON TX 75007-5216
# 412310           DANG, CO T  ...       NaN         HOUSTON TX 77071-3644
# 423101   PHAM, CO DUYEN THI  ...       NaN         HOUSTON TX 77065-5603
# 430516  NGUYEN, CO HONG THI  ...       NaN         GARLAND TX 75040-2701
# 481086      RV ELECTRIC, CO  ...       NaN                           NaN
# 481262  EXCEL ELECTRIC, CO.  ...       NaN          SAN ANTONIO TX 78226
#
#        MAILCOUNTYCODE    MAILCOUNTY MAILZIP   TELEPHONE LICSUBTYPE CEFLAG  \
# 13211             NaN        HARRIS   77083         NaN        CER      N
# 235113           0355        NUECES   78413  3619397371         MA      Y
# 238814           0439       TARRANT   76014  8179913096         MA      N
# 242925           0113        DALLAS   75040  9724159108         MA      N
# 273469           0201        HARRIS   77064  7138849922         FA      N
# 276857           0201        HARRIS   77064  7138849922         MA      N
# 291329           0113        DALLAS   75006  4699518563         MA      N
# 300907           0113        DALLAS   75040  9724159108         FA      N
# 317615           0201        HARRIS   77036  8322311038         MA      N
# 340165           0113        DALLAS   75052  9729745569         MA      N
# 343005           0201        HARRIS   77057  8327239890         FA      N
# 344202           0999  OUT OF STATE   92105  2812408268         MA      N
# 347723           0999  OUT OF STATE    6514  4692260501         MA      N
# 363887           0439       TARRANT   76014  8179913096         EE      N
# 376877           0167     GALVESTON   77518  2818711728         MA      N
# 377562           0201        HARRIS   77034  8323106519         MA      N
# 377682           0113        DALLAS   75244  4692718723         MA      N
# 378177           0999  OUT OF STATE   73162  4057400820         MA      N
# 388524           0201        HARRIS   77072  8327013640         MA      N
# 389186           0121        DENTON   75007  4692265622         MA      N
# 412310           0201        HARRIS   77071  8328302660         ME      N
# 423101           0201        HARRIS   77065  8324883280         MA      N
# 430516           0113        DALLAS   75040  9724159108         ME      N
# 481086            NaN           NaN       0  5123852588         EC      N
# 481262           0029         BEXAR   78226  2106391771         EC      N
#
#         lastname FIRSTNAME
# 13211        LAO        CO
# 235113        VU        CO
# 238814      TRAN        CO
# 242925    NGUYEN        CO
# 273469      TRAN        CO
# 276857      TRAN        CO
# 291329     HUYNH        CO
# 300907    NGUYEN        CO
# 317615      TRAN        CO
# 340165    NGUYEN        CO
# 343005      TRAN        CO
# 344202      PHAN        CO
# 347723        HA        CO
# 363887      TRAN        CO
# 376877       MAI        CO
# 377562        LE        CO
# 377682       DAO        CO
# 378177     THACH        CO
# 388524     HUYNH        CO
# 389186      TRAN        CO
# 412310      DANG        CO
# 423101      PHAM        CO
# 430516    NGUYEN        CO
# 481086  ELECTRIC        CO
# 481262  ELECTRIC        CO
#
# [25 rows x 21 columns]

# %%
df.FIRSTNAME = df.FIRSTNAME.fillna('None')
#For some reason dropna was not working properly -- 
#also there were 82,000 values without a first name so I didn't know if that was too many to drop

# %%
df.FIRSTNAME.isna().value_counts()
# Out:
# False    597816
# Name: FIRSTNAME, dtype: int64

# %%
#df[df.lastname.str.contains('&')]

# %% [markdown]
# My code before only worked for people with middle names, but now it got people without middle names, too. Looking much better!

# %% [markdown]
# ## 25. Most popular first names?

# %%
df.FIRSTNAME.value_counts().head(10)
#Noticing "Inc" and "LLC" here so maybe I need to revisit the regex!
# Out:
# None           81601
# JOSE            7762
# MICHAEL         5885
# DAVID           5379
# MARIA           5282
# JAMES           4946
# JUAN            4569
# ROBERT          4389
# JOHN            4364
# CHRISTOPHER     3138
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 26. Most popular first names for a Cosmetology Operator, Cosmetology Esthetician, Cosmetologist, and anything that seems similar?
#
# If you get an error about "cannot index vector containing NA / NaN values" remember `.fillna(False)` or `na=False` - if a row doesn't have a license, it doesn't give a `True`/`False`, so we force all of the empty rows to be `False`.

# %%
df.FIRSTNAME[df['LICTYPE'].isin(['Cosmetology Operator', 'Cosmetology Esthetician', 'Cosmetologist'])].value_counts()
# Out:
# MARIA       4494
# JENNIFER    1683
# JESSICA     1525
# ASHLEY      1269
# MARY        1204
#             ...
# MARQUISA       1
# EMELITA        1
# SEMMERIA       1
# RAYMIE         1
# KAMIESHA       1
# Name: FIRSTNAME, Length: 21003, dtype: int64

# %% [markdown]
# ## 27. Most popular first names for anything involving electricity?

# %%
df.FIRSTNAME[df['LICTYPE'].str.contains('Electric')].value_counts()
# Out:
# None         10046
# JOSE          5720
# MICHAEL       3547
# JUAN          3335
# DAVID         3315
#              ...
# KENDALE          1
# REGINOLD         1
# AARESH           1
# JERIMEY          1
# ENRIQUETA        1
# Name: FIRSTNAME, Length: 11871, dtype: int64

# %% [markdown]
# ## 28. Can we be any more obnoxious in this assignment?
#
# A terrible thing that data analysts are often guilty of is using names to make assumptions about people. Beyond stereotypes involving last names, first names are often used to predict someone's race, ethnic background, or gender.
#
# And if that isn't bad enough: if we were looking for Python libraries to do this sort of analysis, we'd come across [sex machine](https://github.com/ferhatelmas/sexmachine/). Once upon a time there was Ruby package named sex machine and everyone was like "come on are you six years old? is this how we do things?" and the guy was like "you're completely right I'm renaming it to [gender detector](https://github.com/bmuller/gender_detector)" and the world was Nice and Good again.
#
# How'd it happen? [On Github, in a pull request!](https://github.com/bmuller/gender_detector/pull/14) Neat, right?
#
# But yeah: apparently Python didn't get the message.
#
# The sexmachine package doesn't work on Python 3 because it's from 300 BC, so we're going to use a Python 3 fork with the less problematic name [gender guesser](https://pypi.python.org/pypi/gender-guesser/).
#
# #### Use `pip` or `pip3` to install gender-guesser.

# %%
# !pip install gender-guesser
# Out:
# Requirement already satisfied: gender-guesser in /Users/paromasoni/.pyenv/versions/3.8.2/lib/python3.8/site-packages (0.4.0)
# WARNING: You are using pip version 19.2.3, however version 20.2.4 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# #### Run this code to test to see that it works

# %%
import gender_guesser.detector as gender

detector = gender.Detector(case_sensitive=False)
detector.get_gender('David')
# Out:
# 'male'

# %%
detector.get_gender('Jose')
# Out:
# 'male'

# %%
detector.get_gender('Maria')
# Out:
# 'female'

# %% [markdown]
# #### Use it on a dataframe
#
# To use something fancy like that on a dataframe, you use `.apply`. Check it out:

# %%
df.FIRSTNAME.head()
# Out:
# 0      JIM
# 1      JON
# 2     JUAN
# 3    JAMES
# 4     JOHN
# Name: FIRSTNAME, dtype: object

# %%
#df.dtypes

# %%
#df.FIRSTNAME.apply(lambda name: detector.get_gender(name)).head()
df.FIRSTNAME.apply(lambda name: detector.get_gender(name))
# Out:
# 0         male
# 1         male
# 2         male
# 3         male
# 4         male
#           ...
# 597811    male
# 597812    male
# 597813    male
# 597814    male
# 597815    male
# Name: FIRSTNAME, Length: 597816, dtype: object

# %%
df.FIRSTNAME.isna().value_counts()
# Out:
# False    597816
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 29. Calculate the gender of everyone's first name and save it to a column
#
# Confirm by see how many people of each gender we have

# %%
df.FIRSTNAME.apply(lambda name: detector.get_gender(name)).value_counts()
# Out:
# male             229151
# female           148304
# unknown          130335
# mostly_female     42370
# mostly_male       26619
# andy              21037
# Name: FIRSTNAME, dtype: int64

# %%
df['GENDER'] = df.FIRSTNAME.apply(lambda name: detector.get_gender(name))

# %%
df.head()
# Out:
#                 LICTYPE LICNUMBER BIZCOUNTY                   BIZNAME  \
# 0  Associate Auctioneer      7326  ANGELINA      RISINGER, JIM MARVIN
# 1  Associate Auctioneer      7962    UPSHUR       WILLIAMS, JON ANDRE
# 2  Associate Auctioneer      8406    WILSON     GUEVARA, JUAN ANTONIO
# 3  Associate Auctioneer     10543    HARRIS  BOWERS, JAMES BRISCOE II
# 4  Associate Auctioneer     10642      BELL       DEMSKY, JOHN EDWARD
#
#    BIZLINE1  BIZLINE2  BIZCITYSTATE BIZTELEPHONE EXPIRATION  \
# 0       NaN       NaN           NaN          NaN 2017-08-10
# 1       NaN       NaN           NaN          NaN 2017-12-29
# 2       NaN       NaN           NaN          NaN 2017-09-26
# 3       NaN       NaN           NaN          NaN 2017-11-04
# 4       NaN       NaN           NaN          NaN 2018-02-25
#
#                       OWNER  ...          MAILCITYSTATE MAILCOUNTYCODE  \
# 0      RISINGER, JIM MARVIN  ...   NACOGDOCHES TX 75964           0347
# 1       WILLIAMS, JON ANDRE  ...       KILGORE TX 75662           0183
# 2     GUEVARA, JUAN ANTONIO  ...          POTH TX 78147           0493
# 3  BOWERS, JAMES BRISCOE II  ...  HOUSTON TX 77076-2027           0201
# 4       DEMSKY, JOHN EDWARD  ...      BARTLETT TX 76511           0027
#
#     MAILCOUNTY MAILZIP   TELEPHONE LICSUBTYPE CEFLAG  lastname FIRSTNAME  \
# 0  NACOGDOCHES   75964  9363665745        NaN      N  RISINGER       JIM
# 1        GREGG   75662  9039187899        NaN      N  WILLIAMS       JON
# 2       WILSON   78147         NaN        NaN      N   GUEVARA      JUAN
# 3       HARRIS   77076  7136445566        NaN      N    BOWERS     JAMES
# 4         BELL   76511  2549852228        NaN      N    DEMSKY      JOHN
#
#   GENDER
# 0   male
# 1   male
# 2   male
# 3   male
# 4   male
#
# [5 rows x 22 columns]

# %% [markdown]
# ## 30. We like our data to be in tidy binary categories
#
# * Combine the `mostly_female` into `female`
# * Combine the `mostly_male` into `male`
# * Replace `andy` (androgynous) and `unknown` with `NaN`
#
# you can get NaN not by making a string, but with `import numpy as np` and then using `np.nan`.

# %%
import numpy as np

# %%
df.GENDER = df.GENDER.replace('mostly_female', 'female')
#df[df.GENDER == 'mostly_female']

# %%
df.GENDER = df.GENDER.replace('mostly_male', 'male')
#df[df.GENDER == 'mostly_male']

# %%
df.GENDER = df.GENDER.replace('andy', np.nan)
df.GENDER = df.GENDER.replace('unknown', np.nan)
#df[df.GENDER == 'andy']

# %% [markdown]
# ## 31. Do men or women have more licenses? What is the percentage of unknown genders?

# %%
df.GENDER.value_counts(dropna=False)
# Out:
# male      255770
# female    190674
# NaN       151372
# Name: GENDER, dtype: int64

# %%
df.GENDER.value_counts(dropna=False, normalize=True)*100
# Out:
# male      42.784067
# female    31.895098
# NaN       25.320835
# Name: GENDER, dtype: float64

# %% [markdown]
# ## 32. What are the popular unknown- or ambiguous gender first names?
#
# Yours might be different! Mine is a combination of actual ambiguity, cultural bias and dirty data.

# %%
df.FIRSTNAME[df.GENDER.isna()].value_counts().head(10)
# Out:
# None     81601
# THANH     1555
# TRANG     1144
# INC       1077
# HONG      1027
# DUNG       988
# LINH       910
# LAN        808
# LLC        732
# YEN        625
# Name: FIRSTNAME, dtype: int64

# %% [markdown]
# ## 33. Manually check a few, too
#
# Using [a list of "gender-neutral baby names"](https://www.popsugar.com/family/Gender-Neutral-Baby-Names-34485564), pick a few names and check what results the library gives you.

# %%
#Flynn, Dakota, Alex
df.GENDER[df.FIRSTNAME.isin(['ALEX', 'FLYNN','DAKOTA', 'CODY'])].value_counts()
# Out:
# male    1265
# Name: GENDER, dtype: int64

# %% [markdown]
# ## 34. What are the most popular licenses for men? For women?

# %%
df.LICTYPE[df.GENDER == 'male'].value_counts().head(10)
# Out:
# Apprentice Electrician                      95682
# Journeyman Electrician                      35512
# A/C Technician                              24716
# Master Electrician                          15770
# Cosmetology Operator                        13591
# Cosmetology Manicurist                      10710
# Barber, Class A                              9779
# Tow Truck Operator (Incident Management)     6852
# Tow Truck Operator (Consent Tow)             5781
# Legal Service Contract Sales Rep             5667
# Name: LICTYPE, dtype: int64

# %%
df.LICTYPE[df.GENDER == 'female'].value_counts().head(10)
# Out:
# Cosmetology Operator                114921
# Cosmetology Manicurist               24788
# Cosmetology Esthetician              17151
# Apprentice Electrician                4791
# Cosmetologist                         4613
# Legal Service Contract Sales Rep      4445
# Cosmetology Operator Instructor       4404
# Barber, Class A                       4100
# VSF Employee                          1761
# False                                 1501
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 35. What is the gender breakdown for Property Tax Appraiser? How about anything involving Tow Trucks?
#
# If you're in need, remember your good friend `.fillna(False)` to get rid of NaN values, or `.na=False` with `.str.contains`.

# %%
df.GENDER[df.LICTYPE == 'Property Tax Appraiser'].value_counts()
# Out:
# male      1457
# female    1178
# Name: GENDER, dtype: int64

# %%
df.GENDER[df.LICTYPE.str.contains('Tow Truck')].value_counts()
# Out:
# male      12983
# female      641
# Name: GENDER, dtype: int64

# %% [markdown]
# (By the way, what are those tow truck jobs?)

# %%
df.LICTYPE[df.LICTYPE.str.contains('Tow Truck')].value_counts()
# Out:
# Tow Truck Operator (Incident Management)    7804
# Tow Truck Operator (Consent Tow)            6703
# Tow Truck Operator (Private Property)        352
# Tow Truck Operator Trainee                    53
# Name: LICTYPE, dtype: int64

# %% [markdown]
# ## 33. Graph them!
#
# And let's **give them titles** so we know which is which.

# %%
df.LICTYPE[df.LICTYPE.str.contains('Tow Truck')].value_counts().plot(kind='barh')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 34. Calcuate the supposed gender bias for profession
#
# I spent like an hour on this and then realized a super easy way to do it. Welcome to programming! I'll do this part for you.

# %%
# So when you do .value_counts(), it gives you an index and a value
df[df['GENDER'] == 'male'].LICTYPE.value_counts().head()
# Out:
# Apprentice Electrician    95682
# Journeyman Electrician    35512
# A/C Technician            24716
# Master Electrician        15770
# Cosmetology Operator      13591
# Name: LICTYPE, dtype: int64

# %% [markdown]
# We did `pd.concat` to combine dataframes, but you can also use it to combine series (like the results of `value_counts()`). If you give it a few `value_counts()` and give it some column names it'll make something real nice.

# %%
# All of the values_counts() we will be combining
vc_series = [
    df[df['GENDER'] == 'male'].LICTYPE.value_counts(),
    df[df['GENDER'] == 'female'].LICTYPE.value_counts(),
    df[df['GENDER'].isnull()].LICTYPE.value_counts()
]
# You need axis=1 so it combines them as columns
gender_df = pd.concat(vc_series, axis=1)
gender_df.head()
# Out:
#                         LICTYPE   LICTYPE  LICTYPE
# Apprentice Electrician  95682.0    4791.0  10120.0
# Journeyman Electrician  35512.0    1025.0   1633.0
# A/C Technician          24716.0     880.0   2363.0
# Master Electrician      15770.0     393.0    647.0
# Cosmetology Operator    13591.0  114921.0  22694.0

# %%
# Turn "A/C Contractor" etc into an actual column instead of an index
gender_df.reset_index(inplace=True)
gender_df.head()
# Out:
#                     index  LICTYPE   LICTYPE  LICTYPE
# 0  Apprentice Electrician  95682.0    4791.0  10120.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0
# 2          A/C Technician  24716.0     880.0   2363.0
# 3      Master Electrician  15770.0     393.0    647.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0

# %%
# Rename the columns appropriately
gender_df.columns = ["license", "male", "female", "unknown"]
# Clean up the NaN by replacing them with zeroes
gender_df.fillna(0, inplace=True)
gender_df.head()
# Out:
#                   license     male    female  unknown
# 0  Apprentice Electrician  95682.0    4791.0  10120.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0
# 2          A/C Technician  24716.0     880.0   2363.0
# 3      Master Electrician  15770.0     393.0    647.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0

# %% [markdown]
# ## 35. Add new columns for total licenses, percent known (not percent unknown!), percent male (of known), percent female (of known)
#
# And replace any `NaN`s with `0`.

# %%
gender_df['total_licenses'] = gender_df.male + gender_df.female + gender_df.unknown
gender_df.head()
# Out:
#                   license     male    female  unknown  total_licenses
# 0  Apprentice Electrician  95682.0    4791.0  10120.0        110593.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0         38170.0
# 2          A/C Technician  24716.0     880.0   2363.0         27959.0
# 3      Master Electrician  15770.0     393.0    647.0         16810.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0        151206.0

# %%
gender_df['pct_known'] = ((gender_df.male + gender_df.female) / gender_df.total_licenses) * 100
gender_df.head()
# Out:
#                   license     male    female  unknown  total_licenses  \
# 0  Apprentice Electrician  95682.0    4791.0  10120.0        110593.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0         38170.0
# 2          A/C Technician  24716.0     880.0   2363.0         27959.0
# 3      Master Electrician  15770.0     393.0    647.0         16810.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0        151206.0
#
#    pct_known
# 0  90.849330
# 1  95.721771
# 2  91.548339
# 3  96.151101
# 4  84.991336

# %%
gender_df['pct_male_known'] = (gender_df.male / (gender_df.male + gender_df.female)) * 100
gender_df.head()
# Out:
#                   license     male    female  unknown  total_licenses  \
# 0  Apprentice Electrician  95682.0    4791.0  10120.0        110593.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0         38170.0
# 2          A/C Technician  24716.0     880.0   2363.0         27959.0
# 3      Master Electrician  15770.0     393.0    647.0         16810.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0        151206.0
#
#    pct_known  pct_male_known
# 0  90.849330       95.231555
# 1  95.721771       97.194625
# 2  91.548339       96.561963
# 3  96.151101       97.568521
# 4  84.991336       10.575666

# %%
gender_df['pct_female_known'] = (gender_df.female / (gender_df.male + gender_df.female)) * 100
gender_df.head()
# Out:
#                   license     male    female  unknown  total_licenses  \
# 0  Apprentice Electrician  95682.0    4791.0  10120.0        110593.0
# 1  Journeyman Electrician  35512.0    1025.0   1633.0         38170.0
# 2          A/C Technician  24716.0     880.0   2363.0         27959.0
# 3      Master Electrician  15770.0     393.0    647.0         16810.0
# 4    Cosmetology Operator  13591.0  114921.0  22694.0        151206.0
#
#    pct_known  pct_male_known  pct_female_known
# 0  90.849330       95.231555          4.768445
# 1  95.721771       97.194625          2.805375
# 2  91.548339       96.561963          3.438037
# 3  96.151101       97.568521          2.431479
# 4  84.991336       10.575666         89.424334

# %% [markdown]
# ## 35. What 10 licenses with more than 2,000 people and over 75% "known" gender has the most male owners? The most female?

# %%
gender_df[(gender_df.total_licenses > 2000) & (gender_df.pct_known > 75)].sort_values(by='male', ascending=False).head(10)
# Out:
#                                      license     male    female  unknown  \
# 0                     Apprentice Electrician  95682.0    4791.0  10120.0
# 1                     Journeyman Electrician  35512.0    1025.0   1633.0
# 2                             A/C Technician  24716.0     880.0   2363.0
# 3                         Master Electrician  15770.0     393.0    647.0
# 4                       Cosmetology Operator  13591.0  114921.0  22694.0
# 6                            Barber, Class A   9779.0    4100.0   2140.0
# 7   Tow Truck Operator (Incident Management)   6852.0     344.0    608.0
# 8           Tow Truck Operator (Consent Tow)   5781.0     276.0    646.0
# 9           Legal Service Contract Sales Rep   5667.0    4445.0   1324.0
# 10                                     False   4899.0    1501.0    686.0
#
#     total_licenses  pct_known  pct_male_known  pct_female_known
# 0         110593.0  90.849330       95.231555          4.768445
# 1          38170.0  95.721771       97.194625          2.805375
# 2          27959.0  91.548339       96.561963          3.438037
# 3          16810.0  96.151101       97.568521          2.431479
# 4         151206.0  84.991336       10.575666         89.424334
# 6          16019.0  86.640864       70.458967         29.541033
# 7           7804.0  92.209124       95.219566          4.780434
# 8           6703.0  90.362524       95.443289          4.556711
# 9          11436.0  88.422525       56.042326         43.957674
# 10          7086.0  90.318939       76.546875         23.453125

# %%
gender_df[(gender_df.total_licenses > 2000) & (gender_df.pct_known > 75)].sort_values(by='female', ascending=False).head(10)
# Out:
#                              license     male    female  unknown  \
# 4               Cosmetology Operator  13591.0  114921.0  22694.0
# 17           Cosmetology Esthetician   1597.0   17151.0   4865.0
# 0             Apprentice Electrician  95682.0    4791.0  10120.0
# 9   Legal Service Contract Sales Rep   5667.0    4445.0   1324.0
# 24   Cosmetology Operator Instructor    553.0    4404.0    788.0
# 6                    Barber, Class A   9779.0    4100.0   2140.0
# 20                      VSF Employee   1434.0    1761.0    295.0
# 10                             False   4899.0    1501.0    686.0
# 19            Property Tax Appraiser   1457.0    1178.0    211.0
# 1             Journeyman Electrician  35512.0    1025.0   1633.0
#
#     total_licenses  pct_known  pct_male_known  pct_female_known
# 4         151206.0  84.991336       10.575666         89.424334
# 17         23613.0  79.396942        8.518242         91.481758
# 0         110593.0  90.849330       95.231555          4.768445
# 9          11436.0  88.422525       56.042326         43.957674
# 24          5745.0  86.283725       11.155941         88.844059
# 6          16019.0  86.640864       70.458967         29.541033
# 20          3490.0  91.547278       44.882629         55.117371
# 10          7086.0  90.318939       76.546875         23.453125
# 19          2846.0  92.586086       55.294118         44.705882
# 1          38170.0  95.721771       97.194625          2.805375

# %% [markdown]
# ## 36. Let's say you have to call a few people about being in a profession dominated by the other gender. What are their phone numbers?
#
# This will involve doing some research in one dataframe, then the other one. I didn't put an answer here because I'm interested in what you come up with!

# %%
#gender_df.license[(gender_df.pct_male_known > gender_df.pct_female_known) | (gender_df.pct_female_known > gender_df.pct_male_known)].head(10)

gender_df['LICTYPE'] = gender_df.license[(gender_df.pct_male_known > gender_df.pct_female_known) | (gender_df.pct_female_known > gender_df.pct_male_known)]
gender_df

#I was trying to calculate the difference between percentage of occupation, and then sort by the highest difference
#But I kept getting value errors


# if gender_df.pct_male_known.all() > gender_df.pct_female_known.all():
#     diff = gender_df.pct_male_known - gender_df.pct_female_known
# elif gender_df.pct_male_known.all() < gender_df.pct_female_known.all():
#     diff = gender_df.pct_female_known - gender_df.pct_male_known

#     gender_df['diff'] = diff

# gender_df.head()
#gender_df.license[diff1].sort_values(dropna=True)
# Out:
#                                             license     male    female  \
# 0                            Apprentice Electrician  95682.0    4791.0
# 1                            Journeyman Electrician  35512.0    1025.0
# 2                                    A/C Technician  24716.0     880.0
# 3                                Master Electrician  15770.0     393.0
# 4                              Cosmetology Operator  13591.0  114921.0
# ..                                              ...      ...       ...
# 99                              Booting CE Provider      0.0       0.0
# 100  Mobile Cosmetology Esthetician/Manicure Saloon      0.0       0.0
# 101          Licensed Court Interpreter CE Provider      0.0       0.0
# 102    Mobile Cosmetology Manicure Specialty Saloon      0.0       0.0
# 103                    Legal Service Contract Admin      0.0       0.0
#
#      unknown  total_licenses  pct_known  pct_male_known  pct_female_known  \
# 0    10120.0        110593.0  90.849330       95.231555          4.768445
# 1     1633.0         38170.0  95.721771       97.194625          2.805375
# 2     2363.0         27959.0  91.548339       96.561963          3.438037
# 3      647.0         16810.0  96.151101       97.568521          2.431479
# 4    22694.0        151206.0  84.991336       10.575666         89.424334
# ..       ...             ...        ...             ...               ...
# 99       3.0             3.0   0.000000             NaN               NaN
# 100      2.0             2.0   0.000000             NaN               NaN
# 101      2.0             2.0   0.000000             NaN               NaN
# 102      2.0             2.0   0.000000             NaN               NaN
# 103      1.0             1.0   0.000000             NaN               NaN
#
#                     LICTYPE
# 0    Apprentice Electrician
# 1    Journeyman Electrician
# 2            A/C Technician
# 3        Master Electrician
# 4      Cosmetology Operator
# ..                      ...
# 99                      NaN
# 100                     NaN
# 101                     NaN
# 102                     NaN
# 103                     NaN
#
# [104 rows x 9 columns]

# %%
#df[(df['LICTYPE'] == gender_df['LICTYPE'])]
# ValueError: Can only compare identically-labeled Series objects

# %% [markdown]
# ## Okay, let's take a break for a second.
#
# We've been diving pretty deep into this gender stuff after an initial "oh but it's not great" kind of thing.
#
# **What issues might come up with our analysis?** Some might be about ethics or discrimination, while some might be about our analysis being misleading or wrong. Go back and take a critical look at what we've done since we started working on gender, and summarize your thoughts below.

# %%
#The gender detector package still seems flawed, especially considering names that are "gender neutral" are often viewed as
#either male or female depending on more traditional connotations. Also a number of names are unknown because they are not
#conventional names commonly found in the United States. For eg, Jose and Juan are there but Trang etc. are not.
#There is also lots and lots of unknown data re: professions itself, so it may not be giving us an accurate portrayal of gender and labour breakdowns.

# %% [markdown]
# If you found problems with our analysis, **how could we make improvements?**

# %%
#Either try to find the missing data with documentation/reaching out to the source, or filter with only known values and call it a sample ratehr than accurate data?

# %% [markdown]
# ## PART FIVE: Violations
#
# ### 37. Read in **violations.csv** as `violations_df`, make sure it looks right

# %%
violations_df = pd.read_csv("violations.csv")
violations_df
# Out:
#                                                  basis     city  \
# 0    Respondent failed to keep a record of the date...  HOUSTON
# 1    Respondent failed to keep a record of the date...  HOUSTON
# 2    Respondent failed to maintain the required cle...  HOUSTON
# 3    Respondent failed to keep a record of the date...  HOUSTON
# 4    The Respondent's license was revoked upon Resp...  HOUSTON
# ..                                                 ...      ...
# 110  Respondent failed to clean, disinfect, and ste...  HOUSTON
# 111  Respondent possessed an electric drill other t...  HOUSTON
# 112  Respondent failed to keep a record of the date...  HOUSTON
# 113  Respondent operated a cosmetology salon with a...  HOUSTON
# 114  Respondent failed to clean, disinfect, and ste...  HOUSTON
#
#         complaintno  county licenseno                   name  \
# 0    COS20160024894  HARRIS    748459       NGUYEN, PHUONG T
# 1    COS20170004646  HARRIS    742837     NGUYEN, SUYEN THI
# 2    COS20170007996  HARRIS    729680      NGUYEN, XUONG MY
# 3    COS20170003822  HARRIS    688518   NGUYEN, NHUNG TUYET
# 4    COS20170005470  HARRIS   1209580         NGUYEN, QUAN M
# ..              ...     ...       ...                    ...
# 110  COS20140016481  HARRIS    738145  NGUYEN, KIM DUNG THI
# 111  COS20130017246  HARRIS    721462    NGUYEN, KHOAN VIET
# 112  COS20130020057  HARRIS    743316      NGUYEN, HANG THI
# 113  COS20140020041  HARRIS    724124        NGUYEN, THANH N
# 114  COS20140013051  HARRIS   1439723         NGUYEN, MINH V
#
#                                                  order  orderDate  zipcode
# 0    Respondent is assessed an administrative penal...  3/21/2017    77083
# 1    Respondent is assessed an administrative penal...  3/21/2017    77072
# 2    Respondent is assessed an administrative penal...  3/21/2017    77066
# 3    Respondent is assessed an administrative penal...   3/8/2017    77083
# 4    Respondent's Cosmetology Operator license was ...  2/24/2017    77077
# ..                                                 ...        ...      ...
# 110  Respondent is assessed an administrative penal...  9/29/2014    77087
# 111  Respondent is assessed an administrative penal...   9/9/2014    77061
# 112  Respondent is assessed an administrative penal...   9/8/2014    77021
# 113  Respondent is assessed an administrative penal...   9/4/2014    77075
# 114  Respondent is assessed an administrative penal...  8/12/2014    77064
#
# [115 rows x 9 columns]

# %% [markdown]
# ### 38. Combine with your original licenses dataset dataframe to get phone numbers and addresses for each violation. Check that it is 90 rows, 28 columns.

# %%
merged = violations_df.merge(df, how='left',
                            left_on= 'licenseno', 
                            #left_on= 'name'
                            right_on='LICNUMBER')
                            #right_on='OWNER')
#merged = pd.set_option('display.max_colwidth')
merged.head()
# Out:
#                                                basis     city     complaintno  \
# 0  Respondent failed to keep a record of the date...  HOUSTON  COS20160024894
# 1  Respondent failed to keep a record of the date...  HOUSTON  COS20170004646
# 2  Respondent failed to maintain the required cle...  HOUSTON  COS20170007996
# 3  Respondent failed to keep a record of the date...  HOUSTON  COS20170003822
# 4  The Respondent's license was revoked upon Resp...  HOUSTON  COS20170005470
#
#    county licenseno                  name  \
# 0  HARRIS    748459      NGUYEN, PHUONG T
# 1  HARRIS    742837    NGUYEN, SUYEN THI
# 2  HARRIS    729680     NGUYEN, XUONG MY
# 3  HARRIS    688518  NGUYEN, NHUNG TUYET
# 4  HARRIS   1209580        NGUYEN, QUAN M
#
#                                                order  orderDate  zipcode  \
# 0  Respondent is assessed an administrative penal...  3/21/2017    77083
# 1  Respondent is assessed an administrative penal...  3/21/2017    77072
# 2  Respondent is assessed an administrative penal...  3/21/2017    77066
# 3  Respondent is assessed an administrative penal...   3/8/2017    77083
# 4  Respondent's Cosmetology Operator license was ...  2/24/2017    77077
#
#                                   LICTYPE  ...      MAILCITYSTATE  \
# 0  Cosmetology Esthetician/Manicure Salon  ...   HOUSTON TX 77031
# 1  Cosmetology Esthetician/Manicure Salon  ...  PEARLAND TX 77584
# 2  Cosmetology Esthetician/Manicure Salon  ...    HUMBLE TX 77346
# 3                Cosmetology Beauty Salon  ...   HOUSTON TX 77083
# 4                                     NaN  ...                NaN
#
#   MAILCOUNTYCODE MAILCOUNTY  MAILZIP   TELEPHONE  LICSUBTYPE CEFLAG lastname  \
# 0           0201     HARRIS    77031  7132701521          FM      N     None
# 1           0039   BRAZORIA    77584  8325337866          FM      N     None
# 2           0201     HARRIS    77346  2818525330          FM      N     None
# 3           0201     HARRIS    77083  2814956262          CS      N     None
# 4            NaN        NaN      NaN         NaN         NaN    NaN      NaN
#
#   FIRSTNAME GENDER
# 0      None    NaN
# 1      None    NaN
# 2      None    NaN
# 3      None    NaN
# 4       NaN    NaN
#
# [5 rows x 31 columns]

# %%
#There are 115 rows and 31 columns (the 3 extra columns are the ones we added in, I think) but there were 115 columns in the violations df, so I just left it?

# %% [markdown]
# ## 39. Find each violation involving a failure with records. Use a regular expression.

# %%
violations_df.dtypes
# Out:
# basis          object
# city           object
# complaintno    object
# county         object
# licenseno      object
# name           object
# order          object
# orderDate      object
# zipcode         int64
# dtype: object

# %%
#violations_df.str.extract(r"[\w\W]+fail[\w\W]*record")
violations_df[violations_df.basis.str.contains(r"fail")]
# Out:
#                                                  basis     city  \
# 0    Respondent failed to keep a record of the date...  HOUSTON
# 1    Respondent failed to keep a record of the date...  HOUSTON
# 2    Respondent failed to maintain the required cle...  HOUSTON
# 3    Respondent failed to keep a record of the date...  HOUSTON
# 5    Respondent failed to disinfect shampoo bowls p...  HOUSTON
# ..                                                 ...      ...
# 108  Respondent failed to clean and sanitize whirlp...  BAYTOWN
# 109  Respondent failed to keep a record of the date...  HOUSTON
# 110  Respondent failed to clean, disinfect, and ste...  HOUSTON
# 112  Respondent failed to keep a record of the date...  HOUSTON
# 114  Respondent failed to clean, disinfect, and ste...  HOUSTON
#
#         complaintno  county licenseno                     name  \
# 0    COS20160024894  HARRIS    748459         NGUYEN, PHUONG T
# 1    COS20170004646  HARRIS    742837       NGUYEN, SUYEN THI
# 2    COS20170007996  HARRIS    729680        NGUYEN, XUONG MY
# 3    COS20170003822  HARRIS    688518     NGUYEN, NHUNG TUYET
# 5    COS20160003461  HARRIS    742061  NGUYEN, KIM THUAN-NGOC
# ..              ...     ...       ...                      ...
# 108  COS20130013338  HARRIS    694870       NGUYEN, CINDY THI
# 109  COS20140015709  HARRIS    724124           NGUYEN, LIEM T
# 110  COS20140016481  HARRIS    738145    NGUYEN, KIM DUNG THI
# 112  COS20130020057  HARRIS    743316        NGUYEN, HANG THI
# 114  COS20140013051  HARRIS   1439723           NGUYEN, MINH V
#
#                                                  order  orderDate  zipcode
# 0    Respondent is assessed an administrative penal...  3/21/2017    77083
# 1    Respondent is assessed an administrative penal...  3/21/2017    77072
# 2    Respondent is assessed an administrative penal...  3/21/2017    77066
# 3    Respondent is assessed an administrative penal...   3/8/2017    77083
# 5    Respondent is assessed an administrative penal...   2/3/2017    77074
# ..                                                 ...        ...      ...
# 108  Respondent is assessed an administrative penal...  10/2/2014    77521
# 109  Respondent is assessed an administrative penal...  9/29/2014    77028
# 110  Respondent is assessed an administrative penal...  9/29/2014    77087
# 112  Respondent is assessed an administrative penal...   9/8/2014    77021
# 114  Respondent is assessed an administrative penal...  8/12/2014    77064
#
# [87 rows x 9 columns]

# %% [markdown]
# ## 40. How much money was each fine? Use a regular expression and .str.extract
#
# Unfortunately large and helpful troubleshooting tip: `$` means "end of a line" in regex, so `.extract` isn't going to accept it as a dollar sign. You need to escape it by using `\$` instead.

# %%
violations_df.order.str.extract(r"\$([\d\W]*)").head(10)
# Out:
#         0
# 0    300.
# 1    500.
# 2  1,875.
# 3    375.
# 4     NaN
# 5  1,800.
# 6  1,125.
# 7    750.
# 8    750.
# 9    750.

# %% [markdown]
# ## 41. Clean those results (no commas, no dollar signs, and it should be an integer) and save it to a new column called `fine`
#
# `.replace` is for *entire cells*, you're interested in `.str.replace`, which treats each value like a string, not like a... pandas thing.
#
# `.astype(int)` will convert it into an integer for you.

# %%
violations_df['fine'] = violations_df.order.str.extract(r"\$([\d\W]*)")
violations_df['fine'] = violations_df['fine'].str.replace('[,.]','')
violations_df['fine'] = violations_df['fine'].fillna('None')
violations_df['fine'] = violations_df['fine'].astype(int, errors='ignore')
violations_df.head(20)
# Out:
#                                                 basis     city  \
# 0   Respondent failed to keep a record of the date...  HOUSTON
# 1   Respondent failed to keep a record of the date...  HOUSTON
# 2   Respondent failed to maintain the required cle...  HOUSTON
# 3   Respondent failed to keep a record of the date...  HOUSTON
# 4   The Respondent's license was revoked upon Resp...  HOUSTON
# 5   Respondent failed to disinfect shampoo bowls p...  HOUSTON
# 6   Respondent failed to keep a record of the date...     KATY
# 7   Respondent failed to keep a record of the date...   HUMBLE
# 8   Respondent performed or attempted to perform a...  HOUSTON
# 9   Respondent failed to disinfect tools, implemen...  HOUSTON
# 10  Respondent failed to keep a record of the date...  HOUSTON
# 11  Respondent failed to clean, disinfect, and ste...  HOUSTON
# 12  Respondent failed to dispose of single use ite...  HOUSTON
# 13   Respondent left applicators standing in the wax.  HOUSTON
# 14  Respondent performed or attempted to perform a...  HOUSTON
# 15  Respondent failed to disinfect tools, implemen...  HOUSTON
# 16  Respondent failed to keep a record of the date...  HOUSTON
# 17  Respondent failed to sweep up and deposit hair...     KATY
# 18  Respondent practiced cosmetology services in a...  HOUSTON
# 19  Respondent failed to keep a record of the date...   SPRING
#
#        complaintno  county     licenseno                     name  \
# 0   COS20160024894  HARRIS        748459         NGUYEN, PHUONG T
# 1   COS20170004646  HARRIS        742837       NGUYEN, SUYEN THI
# 2   COS20170007996  HARRIS        729680        NGUYEN, XUONG MY
# 3   COS20170003822  HARRIS        688518     NGUYEN, NHUNG TUYET
# 4   COS20170005470  HARRIS       1209580           NGUYEN, QUAN M
# 5   COS20160003461  HARRIS        742061  NGUYEN, KIM THUAN-NGOC
# 6   COS20160026587  HARRIS        747353      NGUYEN, LEDAI NGOC
# 7   COS20170000591  HARRIS        742122             NGUYEN, NGA
# 8   COS20160015193  HARRIS  Not Licensed            NGUYEN, ANDY
# 9   COS20160018700  HARRIS        742837       NGUYEN, SUYEN THI
# 10  COS20160024172  HARRIS        756241          NGUYEN, IVANNA
# 11  COS20160025554  HARRIS       1288397          NGUYEN, TUYEN T
# 12  COS20160022958  HARRIS        711110         NGUYEN, DUC THI
# 13  COS20160020935  HARRIS        743039            NGUYEN, KIM T
# 14  COS20160012408  HARRIS       1688899    NGUYEN, YEN THI THUY
# 15  COS20160022565  HARRIS        768015          NGUYEN, JOANNA
# 16  COS20160023083  HARRIS        743934          NGUYEN, CHANH V
# 17  COS20160011503  HARRIS        736834          NGUYEN, NELSON
# 18  COS20160020809  HARRIS       1456985     NGUYEN, LE XUAN THI
# 19  COS20160021148  HARRIS        748989         NGUYEN, TRUONG V
#
#                                                 order   orderDate  zipcode  \
# 0   Respondent is assessed an administrative penal...   3/21/2017    77083
# 1   Respondent is assessed an administrative penal...   3/21/2017    77072
# 2   Respondent is assessed an administrative penal...   3/21/2017    77066
# 3   Respondent is assessed an administrative penal...    3/8/2017    77083
# 4   Respondent's Cosmetology Operator license was ...   2/24/2017    77077
# 5   Respondent is assessed an administrative penal...    2/3/2017    77074
# 6   Respondent is assessed an administrative penal...   1/11/2017    77494
# 7   Respondent is assessed an administrative penal...   1/11/2017    77346
# 8   Respondent is assessed an administrative penal...    1/9/2017    77019
# 9   Respondent is assessed an administrative penal...  11/30/2016    77072
# 10  Respondent is assessed an administrative penal...  11/30/2016    77099
# 11  Respondent is assessed an administrative penal...   11/4/2016    77072
# 12  Respondent is assessed an administrative penal...   10/3/2016    77084
# 13  Respondent is assessed an administrative penal...   9/27/2016    77072
# 14  Respondent is assessed an administrative penal...   9/16/2016    77083
# 15  Respondent is assessed an administrative penal...    9/6/2016    77090
# 16  Respondent is assessed an administrative penal...   8/29/2016    77088
# 17  Respondent is assessed an administrative penal...   8/24/2016    77450
# 18  Respondent is assessed an administrative penal...   8/24/2016    77075
# 19  Respondent is assessed an administrative penal...   8/24/2016    77388
#
#     fine
# 0    300
# 1    500
# 2   1875
# 3    375
# 4   None
# 5   1800
# 6   1125
# 7    750
# 8    750
# 9    750
# 10   925
# 11   575
# 12  1000
# 13   550
# 14   500
# 15   750
# 16  1125
# 17   500
# 18   500
# 19  1500

# %% [markdown]
# ## 42. Which orders results in the top fines?

# %%
violations_df.sort_values(by='fine',ascending=False).head(20)
# Out:
#                                                  basis      city  \
# 33   Respondent performed or attempted to perform a...   HOUSTON
# 4    The Respondent's license was revoked upon Resp...   HOUSTON
# 58   Applicant has been convicted of a crime that i...   HOUSTON
# 48   Respondent operated a cosmetology salon with a...   HOUSTON
# 10   Respondent failed to keep a record of the date...   HOUSTON
# 95   Respondent possessed an electric drill other t...   HOUSTON
# 106  Respondent failed to clean and sanitize whirlp...   HOUSTON
# 85   Respondent leased space in a salon to an indiv...   HOUSTON
# 41   Respondent failed to keep a record of the date...   TOMBALL
# 8    Respondent performed or attempted to perform a...   HOUSTON
# 25   Respondent failed to keep a record of the date...   BAYTOWN
# 47   Respondent failed to keep a record of the date...  KINGWOOD
# 45   Respondent failed to clean and sanitize whirlp...   HOUSTON
# 43   Respondent leased space in a salon to an indiv...   HOUSTON
# 96   Respondent failed to clean and sanitize whirlp...   HOUSTON
# 88   Respondent failed to keep a record of the date...      KATY
# 98   Respondent leased space in a salon to an indiv...   HOUSTON
# 35   Respondent failed to keep a record of the date...   TOMBALL
# 99   Respondent leased space in a salon to an indiv...  PASADENA
# 78   Respondent failed to keep a record of the date...   HOUSTON
#
#         complaintno  county        licenseno                      name  \
# 33   COS20160015193  HARRIS     Not Licensed             NGUYEN, ANDY
# 4    COS20170005470  HARRIS          1209580            NGUYEN, QUAN M
# 58   COS20150024158  HARRIS          1593204       NGUYEN, MINH TOAN L
# 48   COS20160003311  HARRIS           743357         NGUYEN, HANH THI
# 10   COS20160024172  HARRIS           756241           NGUYEN, IVANNA
# 95   COS20150004587  HARRIS           671920             NGUYEN, NINA
# 106  COS20140021128  HARRIS           679804      NGUYEN, DANNY DUONG
# 85   COS20150002684  HARRIS           744671              NGUYEN, TU T
# 41   COS20160008123  HARRIS           739716  NGUYEN, KENNEDY DANG KH
# 8    COS20160015193  HARRIS     Not Licensed             NGUYEN, ANDY
# 25   COS20160010970  HARRIS           750292              NGUYEN, NGA
# 47   COS20160001723  HARRIS           743463      NGUYEN, LANCHI QUOC
# 45   COS20160006443  HARRIS           755851            NGUYEN, THAO M
# 43   COS20160008193  HARRIS           762338        NGUYEN, NAM TRONG
# 96   COS20130018039  HARRIS           694394        NGUYEN, CHAU MINH
# 88   COS20150011843  HARRIS  689733, 1306778      NGUYEN, THUY TRANG N
# 98   COS20150004764  HARRIS           729985  NGUYEN, TIFFANY THOM TH
# 35   COS20160012011  HARRIS           745664             NGUYEN, HAU V
# 99   COS20150008596  HARRIS           750887           NGUYEN, CY VAN
# 78   COS20150011589  HARRIS     671414, 5111             NGUYEN, XUAN
#
#                                                  order   orderDate  zipcode  \
# 33   Respondent is ordered to immediately cease and...   5/17/2016    77019
# 4    Respondent's Cosmetology Operator license was ...   2/24/2017    77077
# 58   The Respondent's Cosmetology Manicurist licens...   12/1/2015    77067
# 48   Respondent is assessed an administrative penal...    2/8/2016    77049
# 10   Respondent is assessed an administrative penal...  11/30/2016    77099
# 95   Respondent is assessed an administrative penal...    4/7/2015    77084
# 106  Respondent is assessed an administrative penal...   11/6/2014    77090
# 85   Respondent is assessed an administrative penal...    7/6/2015    77075
# 41   Respondent is assessed an administrative penal...   3/28/2016    77377
# 8    Respondent is assessed an administrative penal...    1/9/2017    77019
# 25   Respondent is assessed an administrative penal...   7/18/2016    77520
# 47   Respondent is assessed an administrative penal...    2/9/2016    77339
# 45   Respondent is assessed an administrative penal...   2/25/2016    77084
# 43   Respondent is assessed an administrative penal...   3/14/2016    77071
# 96   Respondent is assessed an administrative penal...   3/27/2015    77021
# 88   Respondent is assessed an administrative penal...    7/6/2015    77450
# 98   Respondent is assessed an administrative penal...   3/19/2015    77041
# 35   Respondent is assessed an administrative penal...    5/2/2016    77377
# 99   Respondent is assessed an administrative penal...   3/12/2015    77505
# 78   Respondent is assessed an administrative penal...   7/20/2015    77070
#
#      fine
# 33   None
# 4    None
# 58   None
# 48    975
# 10    925
# 95    875
# 106   875
# 85    875
# 41    850
# 8     750
# 25    750
# 47    750
# 45    750
# 43    750
# 96    750
# 88    750
# 98    750
# 35    750
# 99    750
# 78    750

# %% [markdown]
# ## 43. Are you still here???
#
# I'm sure impressed.

# %%
#Just barely.
